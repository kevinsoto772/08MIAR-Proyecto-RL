# %% [markdown]
# # Actividad - Proyecto práctico
#
#
# > La actividad se desarrollará en grupos pre-definidos de 4 alumnos. Se debe indicar los nombres en orden alfabético (de apellidos). Recordad que esta actividad se corresponde con un 30% de la nota final de la asignatura. Se debe entregar entregar el trabajo en la presente notebook.
# *   Alumno 1: Julián David Gamboa García
# *   Alumno 2: Daniel Enrique Guzmán Reyes
# *   Alumno 3: Kevin Omar Soto Simanca
# *   Alumno 4:

# %% [markdown]
# ---
# ## **PARTE 1** - Instalación y requisitos previos
#
# > Las prácticas han sido preparadas para poder realizarse en el entorno de trabajo de Google Colab. Sin embargo, esta plataforma presenta ciertas incompatibilidades a la hora de visualizar la renderización en gym. Por ello, para obtener estas visualizaciones, se deberá trasladar el entorno de trabajo a local. Por ello, el presente dosier presenta instrucciones para poder trabajar en ambos entornos. Siga los siguientes pasos para un correcto funcionamiento:
# 1.   **LOCAL:** Preparar el enviroment, siguiendo las intrucciones detalladas en la sección *1.1.Preparar enviroment*.
# 2.  **AMBOS:** Modificar las variables "mount" y "drive_mount" a la carpeta de trabajo en drive en el caso de estar en Colab, y ejecturar la celda *1.2.Localizar entorno de trabajo*.
# 3. **COLAB:** se deberá ejecutar las celdas correspondientes al montaje de la carpeta de trabajo en Drive. Esta corresponde a la sección *1.3.Montar carpeta de datos local*.
# 4.  **AMBOS:** Instalar las librerías necesarias, siguiendo la sección *1.4.Instalar librerías necesarias*.

# %% [markdown]
# ---
# ### 1.1. Preparar enviroment (solo local)
#
#
#
# > Para preparar el entorno de trabajo en local, se han seguido los siguientes pasos:
# 1. En Windows, puede ser necesario instalar las C++ Build Tools. Para ello, siga los siguientes pasos. Alternativamente puedes utilizar WSL2: https://towardsdatascience.com/how-to-install-openai-gym-in-a-windows-environment-338969e24d30.
# 2. Instalar Anaconda
# 3. Siguiendo el código que se presenta comentado en la próxima celda: Crear un enviroment, cambiar la ruta de trabajo, e instalar librerías básicas.
#
#
# ```
# conda create --name miar_rl python=3.8
# conda activate miar_rl
# cd "PATH_TO_FOLDER"
# conda install git
# pip install jupyter
# ```
#
#
# 4. Abrir la notebook con *jupyter-notebook*.
#
#
#
# ```
# jupyter-notebook
# ```

# %% [markdown]
# ---
# ### 1.2. Localizar entorno de trabajo: Google colab o local

# %%
# ATENCIÓN!! Modificar ruta relativa a la práctica si es distinta (drive_root)
import os

mount=''
drive_root = ''
IN_COLAB = False

drive_root = r"C:\Users\kevin\Downloads\ESTUDIO MASTER EN IA\Aprendizaje por refuerzo\PROYECTO\Proyecto RL"

os.makedirs(drive_root, exist_ok=True)
os.chdir(drive_root)

print("IN_COLAB:", IN_COLAB)
print("Carpeta de trabajo:", os.getcwd())

try:
  from google.colab import drive
  IN_COLAB=True
except:
  IN_COLAB=False
# Out:
# IN_COLAB: False
# Carpeta de trabajo: C:\Users\kevin\Downloads\ESTUDIO MASTER EN IA\Aprendizaje por refuerzo\PROYECTO\Proyecto RL

# %% [markdown]
# ---
# ### 1.3. Montar carpeta de datos local (solo Colab)

# %%
# Switch to the directory on the Google Drive that you want to use
import os
if IN_COLAB:
  print("We're running Colab")

  if IN_COLAB:
    # Mount the Google Drive at mount
    print("Colab: mounting Google drive on ", mount)

    drive.mount(mount)

    # Create drive_root if it doesn't exist
    create_drive_root = True
    if create_drive_root:
      print("\nColab: making sure ", drive_root, " exists.")
      os.makedirs(drive_root, exist_ok=True)

    # Change to the directory
    print("\nColab: Changing directory to ", drive_root)
    # %cd $drive_root
# Verify we're in the correct working directory
# %pwd
print("Archivos en el directorio: ")
print(os.listdir())
# Out:
# Archivos en el directorio:
# ['.ipynb_checkpoints', 'checkpoint', 'dqn_Acrobot-v1_p1_best.h5f.data-00000-of-00001', 'dqn_Acrobot-v1_p1_best.h5f.index', 'dqn_Acrobot-v1_p1_best_score.txt', 'dqn_Acrobot-v1_p1_log.json', 'dqn_Acrobot-v1_p1_weights.h5f.data-00000-of-00001', 'dqn_Acrobot-v1_p1_weights.h5f.index', 'dqn_Acrobot-v1_p1_weights_10000.h5f.data-00000-of-00001', 'dqn_Acrobot-v1_p1_weights_10000.h5f.index', 'dqn_Acrobot-v1_p1_weights_20000.h5f.data-00000-of-00001', 'dqn_Acrobot-v1_p1_weights_20000.h5f.index', 'dqn_Acrobot-v1_p1_weights_30000.h5f.data-00000-of-00001', 'dqn_Acrobot-v1_p1_weights_30000.h5f.index', 'dqn_Acrobot-v1_p1_weights_40000.h5f.data-00000-of-00001', 'dqn_Acrobot-v1_p1_weights_40000.h5f.index', 'dqn_Acrobot-v1_p1_weights_50000.h5f.data-00000-of-00001', 'dqn_Acrobot-v1_p1_weights_50000.h5f.index', 'dqn_Acrobot-v1_p1_weights_60000.h5f.data-00000-of-00001', 'dqn_Acrobot-v1_p1_weights_60000.h5f.index', 'dqn_Acrobot-v1_p1_weights_70000.h5f.data-00000-of-00001', 'dqn_Acrobot-v1_p1_weights_70000.h5f.index', 'dqn_Acrobot-v1_p1_weights_80000.h5f.data-00000-of-00001', 'dqn_Acrobot-v1_p1_weights_80000.h5f.index', 'videos_proyecto']

# %% [markdown]
# ---
# ### 1.4. Instalar librerías necesarias

# %%
if IN_COLAB:
  # Downgrade to TF 2.15 to ensure Keras 2 compatibility for keras-rl2
  # %pip install tensorflow==2.15.0
  # %pip install numpy==1.26.4
  # %pip install keras==2.15.0
  # %pip install gym==0.17.3
  # %pip install keras-rl2==1.0.5
else:
  # %pip install tensorflow==2.15.0
  # %pip install numpy==1.26.4
  # %pip install keras==2.15.0
  # %pip install gym==0.17.3
  # %pip install keras-rl2==1.0.5
# Out:
# ERROR: Could not find a version that satisfies the requirement tensorflow==2.15.0 (from versions: 2.2.0, 2.2.1, 2.2.2, 2.2.3, 2.3.0, 2.3.1, 2.3.2, 2.3.3, 2.3.4, 2.4.0, 2.4.1, 2.4.2, 2.4.3, 2.4.4, 2.5.0, 2.5.1, 2.5.2, 2.5.3, 2.6.0rc0, 2.6.0rc1, 2.6.0rc2, 2.6.0, 2.6.1, 2.6.2, 2.6.3, 2.6.4, 2.6.5, 2.7.0rc0, 2.7.0rc1, 2.7.0, 2.7.1, 2.7.2, 2.7.3, 2.7.4, 2.8.0rc0, 2.8.0rc1, 2.8.0, 2.8.1, 2.8.2, 2.8.3, 2.8.4, 2.9.0rc0, 2.9.0rc1, 2.9.0rc2, 2.9.0, 2.9.1, 2.9.2, 2.9.3, 2.10.0rc0, 2.10.0rc1, 2.10.0rc2, 2.10.0rc3, 2.10.0, 2.10.1, 2.11.0rc0, 2.11.0rc1, 2.11.0rc2, 2.11.0, 2.11.1, 2.12.0rc0, 2.12.0rc1, 2.12.0, 2.12.1, 2.13.0rc0, 2.13.0rc1, 2.13.0rc2, 2.13.0, 2.13.1)
# ERROR: No matching distribution found for tensorflow==2.15.0
#
# [notice] A new release of pip is available: 23.0.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Ignored the following versions that require a different python version: 1.25.0 Requires-Python >=3.9; 1.25.1 Requires-Python >=3.9; 1.25.2 Requires-Python >=3.9; 1.26.0 Requires-Python <3.13,>=3.9; 1.26.1 Requires-Python <3.13,>=3.9; 1.26.2 Requires-Python >=3.9; 1.26.3 Requires-Python >=3.9; 1.26.4 Requires-Python >=3.9; 2.0.0 Requires-Python >=3.9; 2.0.1 Requires-Python >=3.9; 2.0.2 Requires-Python >=3.9; 2.1.0 Requires-Python >=3.10; 2.1.1 Requires-Python >=3.10; 2.1.2 Requires-Python >=3.10; 2.1.3 Requires-Python >=3.10; 2.2.0 Requires-Python >=3.10; 2.2.1 Requires-Python >=3.10; 2.2.2 Requires-Python >=3.10; 2.2.3 Requires-Python >=3.10; 2.2.4 Requires-Python >=3.10; 2.2.5 Requires-Python >=3.10; 2.2.6 Requires-Python >=3.10; 2.3.0 Requires-Python >=3.11; 2.3.1 Requires-Python >=3.11; 2.3.2 Requires-Python >=3.11; 2.3.3 Requires-Python >=3.11; 2.3.4 Requires-Python >=3.11; 2.3.5 Requires-Python >=3.11; 2.4.0 Requires-Python >=3.11; 2.4.0rc1 Requires-Python >=3.11; 2.4.1 Requires-Python >=3.11; 2.4.2 Requires-Python >=3.11; 2.4.3 Requires-Python >=3.11; 2.4.4 Requires-Python >=3.11; 2.4.5 Requires-Python >=3.11; 2.4.6 Requires-Python >=3.11; 2.5.0 Requires-Python >=3.12; 2.5.0rc1 Requires-Python >=3.12
# ERROR: Could not find a version that satisfies the requirement numpy==1.26.4 (from versions: 1.3.0, 1.4.1, 1.5.0, 1.5.1, 1.6.0, 1.6.1, 1.6.2, 1.7.0, 1.7.1, 1.7.2, 1.8.0, 1.8.1, 1.8.2, 1.9.0, 1.9.1, 1.9.2, 1.9.3, 1.10.0.post2, 1.10.1, 1.10.2, 1.10.4, 1.11.0, 1.11.1, 1.11.2, 1.11.3, 1.12.0, 1.12.1, 1.13.0, 1.13.1, 1.13.3, 1.14.0, 1.14.1, 1.14.2, 1.14.3, 1.14.4, 1.14.5, 1.14.6, 1.15.0, 1.15.1, 1.15.2, 1.15.3, 1.15.4, 1.16.0, 1.16.1, 1.16.2, 1.16.3, 1.16.4, 1.16.5, 1.16.6, 1.17.0, 1.17.1, 1.17.2, 1.17.3, 1.17.4, 1.17.5, 1.18.0, 1.18.1, 1.18.2, 1.18.3, 1.18.4, 1.18.5, 1.19.0, 1.19.1, 1.19.2, 1.19.3, 1.19.4, 1.19.5, 1.20.0, 1.20.1, 1.20.2, 1.20.3, 1.21.0, 1.21.1, 1.21.2, 1.21.3, 1.21.4, 1.21.5, 1.21.6, 1.22.0, 1.22.1, 1.22.2, 1.22.3, 1.22.4, 1.23.0, 1.23.1, 1.23.2, 1.23.3, 1.23.4, 1.23.5, 1.24.0, 1.24.1, 1.24.2, 1.24.3, 1.24.4)
# ERROR: No matching distribution found for numpy==1.26.4
#
# [notice] A new release of pip is available: 23.0.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Collecting keras==2.15.0
#   Using cached keras-2.15.0-py3-none-any.whl (1.7 MB)
# Installing collected packages: keras
#   Attempting uninstall: keras
#     Found existing installation: keras 2.13.1
#     Uninstalling keras-2.13.1:
#       Successfully uninstalled keras-2.13.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.13.1 requires keras<2.14,>=2.13.1, but you have keras 2.15.0 which is incompatible.
# Successfully installed keras-2.15.0
#
# [notice] A new release of pip is available: 23.0.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: gym==0.17.3 in ./.venv/lib/python3.8/site-packages (0.17.3)
# Requirement already satisfied: scipy in ./.venv/lib/python3.8/site-packages (from gym==0.17.3) (1.10.1)
# Requirement already satisfied: numpy>=1.10.4 in ./.venv/lib/python3.8/site-packages (from gym==0.17.3) (1.24.3)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in ./.venv/lib/python3.8/site-packages (from gym==0.17.3) (1.5.0)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in ./.venv/lib/python3.8/site-packages (from gym==0.17.3) (1.6.0)
# Requirement already satisfied: future in ./.venv/lib/python3.8/site-packages (from pyglet<=1.5.0,>=1.4.0->gym==0.17.3) (1.0.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: keras-rl2==1.0.5 in ./.venv/lib/python3.8/site-packages (1.0.5)
# Requirement already satisfied: tensorflow in ./.venv/lib/python3.8/site-packages (from keras-rl2==1.0.5) (2.13.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in ./.venv/lib/python3.8/site-packages (from tensorflow->keras-rl2==1.0.5) (0.34.0)
# Requirement already satisfied: typing-extensions<4.6.0,>=3.6.6 in ./.venv/lib/python3.8/site-packages (from tensorflow->keras-rl2==1.0.5) (4.5.0)
# Requirement already satisfied: absl-py>=1.0.0 in ./.venv/lib/python3.8/site-packages (from tensorflow->keras-rl2==1.0.5) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in ./.venv/lib/python3.8/site-packages (from tensorflow->keras-rl2==1.0.5) (1.6.3)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in ./.venv/lib/python3.8/site-packages (from tensorflow->keras-rl2==1.0.5) (0.4.0)
# Requirement already satisfied: setuptools in ./.venv/lib/python3.8/site-packages (from tensorflow->keras-rl2==1.0.5) (56.0.0)
# Requirement already satisfied: numpy<=1.24.3,>=1.22 in ./.venv/lib/python3.8/site-packages (from tensorflow->keras-rl2==1.0.5) (1.24.3)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in ./.venv/lib/python3.8/site-packages (from tensorflow->keras-rl2==1.0.5) (4.25.9)
# Requirement already satisfied: packaging in ./.venv/lib/python3.8/site-packages (from tensorflow->keras-rl2==1.0.5) (26.2)
# Requirement already satisfied: libclang>=13.0.0 in ./.venv/lib/python3.8/site-packages (from tensorflow->keras-rl2==1.0.5) (18.1.1)
# Collecting keras<2.14,>=2.13.1
#   Using cached keras-2.13.1-py3-none-any.whl (1.7 MB)
# Requirement already satisfied: opt-einsum>=2.3.2 in ./.venv/lib/python3.8/site-packages (from tensorflow->keras-rl2==1.0.5) (3.4.0)
# Requirement already satisfied: flatbuffers>=23.1.21 in ./.venv/lib/python3.8/site-packages (from tensorflow->keras-rl2==1.0.5) (25.12.19)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in ./.venv/lib/python3.8/site-packages (from tensorflow->keras-rl2==1.0.5) (2.13.0)
# Requirement already satisfied: termcolor>=1.1.0 in ./.venv/lib/python3.8/site-packages (from tensorflow->keras-rl2==1.0.5) (2.4.0)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0 in ./.venv/lib/python3.8/site-packages (from tensorflow->keras-rl2==1.0.5) (2.13.0)
# Requirement already satisfied: wrapt>=1.11.0 in ./.venv/lib/python3.8/site-packages (from tensorflow->keras-rl2==1.0.5) (2.0.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in ./.venv/lib/python3.8/site-packages (from tensorflow->keras-rl2==1.0.5) (1.70.0)
# Requirement already satisfied: h5py>=2.9.0 in ./.venv/lib/python3.8/site-packages (from tensorflow->keras-rl2==1.0.5) (3.11.0)
# Requirement already satisfied: google-pasta>=0.1.1 in ./.venv/lib/python3.8/site-packages (from tensorflow->keras-rl2==1.0.5) (0.2.0)
# Requirement already satisfied: six>=1.12.0 in ./.venv/lib/python3.8/site-packages (from tensorflow->keras-rl2==1.0.5) (1.17.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in ./.venv/lib/python3.8/site-packages (from astunparse>=1.6.0->tensorflow->keras-rl2==1.0.5) (0.45.1)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in ./.venv/lib/python3.8/site-packages (from tensorboard<2.14,>=2.13->tensorflow->keras-rl2==1.0.5) (1.0.0)
# Requirement already satisfied: werkzeug>=1.0.1 in ./.venv/lib/python3.8/site-packages (from tensorboard<2.14,>=2.13->tensorflow->keras-rl2==1.0.5) (3.0.6)
# Requirement already satisfied: markdown>=2.6.8 in ./.venv/lib/python3.8/site-packages (from tensorboard<2.14,>=2.13->tensorflow->keras-rl2==1.0.5) (3.7)
# Requirement already satisfied: requests<3,>=2.21.0 in ./.venv/lib/python3.8/site-packages (from tensorboard<2.14,>=2.13->tensorflow->keras-rl2==1.0.5) (2.32.4)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in ./.venv/lib/python3.8/site-packages (from tensorboard<2.14,>=2.13->tensorflow->keras-rl2==1.0.5) (0.7.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in ./.venv/lib/python3.8/site-packages (from tensorboard<2.14,>=2.13->tensorflow->keras-rl2==1.0.5) (2.50.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./.venv/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow->keras-rl2==1.0.5) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in ./.venv/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow->keras-rl2==1.0.5) (45.0.7)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in ./.venv/lib/python3.8/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow->keras-rl2==1.0.5) (2.0.0)
# Requirement already satisfied: importlib-metadata>=4.4 in ./.venv/lib/python3.8/site-packages (from markdown>=2.6.8->tensorboard<2.14,>=2.13->tensorflow->keras-rl2==1.0.5) (8.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow->keras-rl2==1.0.5) (2026.6.17)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow->keras-rl2==1.0.5) (2.2.3)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow->keras-rl2==1.0.5) (3.15)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow->keras-rl2==1.0.5) (3.4.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in ./.venv/lib/python3.8/site-packages (from werkzeug>=1.0.1->tensorboard<2.14,>=2.13->tensorflow->keras-rl2==1.0.5) (2.1.5)
# Requirement already satisfied: cffi>=1.14 in ./.venv/lib/python3.8/site-packages (from cryptography>=38.0.3->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow->keras-rl2==1.0.5) (1.17.1)
# Requirement already satisfied: zipp>=3.20 in ./.venv/lib/python3.8/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.14,>=2.13->tensorflow->keras-rl2==1.0.5) (3.20.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in ./.venv/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow->keras-rl2==1.0.5) (0.6.3)
# Requirement already satisfied: oauthlib>=3.0.0 in ./.venv/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow->keras-rl2==1.0.5) (3.3.1)
# Requirement already satisfied: pycparser in ./.venv/lib/python3.8/site-packages (from cffi>=1.14->cryptography>=38.0.3->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow->keras-rl2==1.0.5) (2.23)
# Installing collected packages: keras
#   Attempting uninstall: keras
#     Found existing installation: keras 2.15.0
#     Uninstalling keras-2.15.0:
#       Successfully uninstalled keras-2.15.0
# Successfully installed keras-2.13.1
#
# [notice] A new release of pip is available: 23.0.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ---
# ## **PARTE 2**. Enunciado
#
# Consideraciones a tener en cuenta:
#
# - El entorno sobre el que trabajaremos será el indicado en el listado correspondien de cada grupo y el algoritmo que usaremos será _DQN_.
#
# - Para nuestro ejercicio, el requisito mínimo será alcanzado cuando el agente consiga una **media de recompensa por encima de los puntos indicados en el listado por grupos en modo test**. Por ello, esta media de la recompensa se calculará a partir del código de test en la última celda del notebook.
#
# Este proyecto práctico consta de tres partes:
#
# 1.   Implementar la red neuronal que se usará en la solución
# 2.   Implementar las distintas piezas de la solución DQN y probar al menos 3 propuestas diferentes de mejora.
# 3.   Justificar la respuesta en relación a los resultados obtenidos e incluir al menos 3 gráficas relevantes comparando las 3 propuestas.
#
# **Rúbrica**: Se valorará la originalidad en la solución aportada, así como la capacidad de discutir los resultados de forma detallada. El requisito mínimo servirá para aprobar la actividad, bajo premisa de que la discusión del resultado sera apropiada.
#
# IMPORTANTE:
#
# * Si no se consigue una puntuación óptima, responder sobre la mejor puntuación obtenida.
# * Para entrenamientos largos, recordad que podéis usar checkpoints de vuestros modelos para retomar los entrenamientos. En este caso, recordad cambiar los parámetros adecuadamente (sobre todo los relacionados con el proceso de exploración).
# * Se deberá entregar unicamente el notebook y los pesos del mejor modelo en un fichero .zip, de forma organizada.
# * Cada alumno deberá de subir la solución de forma individual.

# %% [markdown]
# ---
# ## **PARTE 3**. Desarrollo y preguntas

# %% [markdown]
# ### Funcionamiento del Entorno: Acrobot-v1
#
# Físicamente, se trata de un sistema conocido como péndulo doble subactuado.
#
# 1. La Física del Juego (Mecánica)
#
# El robot está compuesto por dos segmentos (eslabones) conectados por dos articulaciones:
#
# - El Hombro: Está fijo en una posición central y gira libremente respondiendo a la inercia y la gravedad.
#
# - El Codo: Es la unión entre el primer y el segundo brazo. Esta es la única articulación motorizada que el agente puede controlar.
#
# 2. Sistema de Puntuación (Ganar y Perder)
#
# Acrobot es un desafío de optimización de tiempo. No ganas puntos por hacer piruetas; el objetivo es salir del estado inicial lo más rápido posible.
#
# **¿Cómo se gana?**
#
# En la parte superior del entorno existe una línea horizontal objetivo. El episodio se considera superado en el instante exacto en que la punta inferior del segundo brazo logra cruzar por encima de esa línea gracias al balanceo.
#
# **El Castigo y la Puntuación**
#
# Penalización continua: El agente recibe una recompensa estricta de -1 punto por cada paso de tiempo que transcurre sin haber cruzado la meta.
#
# **¿Cómo se pierde?**: El juego tiene un límite de 500 pasos máximos por episodio. Si el agente no logra cruzar la meta al llegar al paso 500, el entorno detiene la simulación automáticamente.
#
# Interpretación del puntaje: Debido a los números negativos, un valor más cercano a cero es un mejor resultado.
#
# Puntuación de -500: El agente fracasó y se agotó el tiempo.
#
# Puntuación de -75: Excelente desempeño; el agente aprendió la técnica para generar impulso y cruzó la meta en tan solo 75 movimientos rápidos.

# %% [markdown]
# #### Importar librerías

# %%
os.environ['TF_USE_LEGACY_KERAS']="1"

# %%
#Comprobamos que se carga la versión esperada de TF y detecta la GPU
import tensorflow as tf1
print(tf1.__version__)
print(tf1.config.list_physical_devices('GPU'))
print(tf1.config.list_logical_devices('GPU'))
# Out:
# 2.5.3
# []
# []

# %%
import tensorflow.keras as tf
from keras import __version__
tf.__version__ = __version__

print(tf.__version__)
# Out:
# 2.5.0

# %%
from __future__ import division

import numpy as np
import gym

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Flatten, Permute

if IN_COLAB:
  from tensorflow.keras.optimizers.legacy import Adam
else:
  from tensorflow.keras.optimizers import Adam

import tensorflow.keras.backend as K

from rl.agents.dqn import DQNAgent
from rl.policy import LinearAnnealedPolicy, BoltzmannQPolicy, EpsGreedyQPolicy
from rl.memory import SequentialMemory
from rl.core import Processor
from rl.callbacks import FileLogger, ModelIntervalCheckpoint

# %% [markdown]
# #### Configuración base

# %%
#Descomentar y adaptar a cada entorno según corresponda

WINDOW_LENGTH = 1
#
env_name = 'Acrobot-v1'
env = gym.make(env_name)

np.random.seed(123)
env.seed(123)
nb_actions = env.action_space.n

# %%
class AcrobotProcessor(Processor):
    def process_observation(self, observation):
        # Acrobot devuelve un vector 1D de 6 valores.
        # Simplemente nos aseguramos de que sea un array de tipo float32.
        return np.array(observation, dtype='float32')

    def process_state_batch(self, batch):
        # Devolvemos el batch tal cual. ¡NO dividimos por 255!
        return batch

    def process_reward(self, reward):
        # Acrobot otorga una recompensa de -1 por cada paso que no llega a la meta,
        # y 0 cuando llega. No necesitamos recortar las recompensas.
        return reward

# %% [markdown]
# Arquitectura de la Red Neuronal
#
# El "cerebro" del agente se construyó utilizando un Perceptrón Multicapa (MLP) a través de la API Sequential de Keras. Su objetivo es mapear el estado actual del entorno hacia el valor Q (recompensa futura esperada) de cada acción posible.
#
# 1. Capa de Entrada (Flatten): El entorno Acrobot devuelve un vector de observación de 6 variables continuas. Dado que keras-rl2 utiliza una ventana de tiempo (window_length=1), los datos ingresan con una forma de (1, 6). La capa Flatten es indispensable para aplanar esta matriz a un vector 1D que las capas densas puedan procesar.
#
# 2. Capas Ocultas (Dense): Se implementaron 3 capas ocultas de 64 neuronas cada una.
#
# Justificación: El entorno de Acrobot tiene dinámicas no lineales complejas (física de péndulos interactuando). Tres capas de 64 nodos ofrecen la profundidad matemática suficiente para extraer estas características sin caer en un sobreajuste (overfitting) o hacer el entrenamiento excesivamente lento.
#
# Activación (ReLU): Se utilizó la función de activación Rectified Linear Unit. Es el estándar en redes profundas porque evita el problema de la desaparición del gradiente, permitiendo que la red aprenda más rápido.
#
# 3. Capa de Salida (Dense): Consta de 3 neuronas (una para cada acción: fuerza izquierda, inercia, fuerza derecha).
#
# Activación (Linear): A diferencia de los problemas de clasificación que usan Softmax (para dar probabilidades del 0 al 1), aquí usamos activación lineal pura. Esto se debe a que el modelo debe predecir Valores Q, los cuales son estimaciones de puntuaciones que pueden ser números negativos grandes (ej. -85.5).

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten

# 1. Obtenemos las dimensiones correctas del entorno
obs_shape = env.observation_space.shape
nb_actions = env.action_space.n

# 2. Construimos la red con el input_shape explícito
model = Sequential()
# Usamos (1,) + obs_shape para que coincida con el formato de keras-rl2
model.add(Flatten(input_shape=(1,) + obs_shape))
model.add(Dense(64, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(nb_actions, activation='linear'))

# Verifica la arquitectura (opcional, pero recomendado)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 6)                 0
# _________________________________________________________________
# dense (Dense)                (None, 64)                448
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 195
# =================================================================
# Total params: 8,963
# Trainable params: 8,963
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 2. Implementación de la solución DQN

# %% [markdown]
# Lógica del Agente (Parámetros DQN)
#
# El agente DQNAgent coordina el entrenamiento. Sus hiperparámetros fueron seleccionados para garantizar estabilidad:
#
# Memoria de Experiencia (SequentialMemory): Capacidad de 50,000 transiciones.
#
# Justificación: En lugar de aprender del último fotograma (lo cual generaría sesgos temporales porque un fotograma se parece mucho al anterior), el agente guarda sus experiencias y toma "lotes aleatorios" del pasado para aprender. Esto estabiliza drásticamente el entrenamiento.
#
# Política de Exploración (LinearAnnealedPolicy + EpsGreedyQPolicy):
#
# Justificación: Para que el agente descubra cómo balancearse, primero debe intentar cosas al azar. La política hace decaer la probabilidad de tomar acciones aleatorias (épsilon) de manera lineal a lo largo de 30,000 pasos. Eventualmente, el agente deja de explorar y comienza a "explotar" el conocimiento adquirido en su red neuronal.
#
# Factor de Descuento (gamma = 0.99):
#
# Justificación: Al ser muy cercano a 1, el agente prioriza altamente las recompensas a largo plazo (llegar a la meta) por encima de las recompensas inmediatas. Es crucial en Acrobot, donde el éxito requiere planeación de varios pasos (balancearse varias veces antes de subir).
#
# Actualización de la Red Objetivo (target_model_update = 10000):
#
# Justificación: DQN utiliza dos redes (una principal que aprende y una objetivo que guía). Si el "objetivo" se mueve constantemente, el agente nunca converge. Congelar la red objetivo y actualizarla solo cada 10,000 pasos proporciona un blanco fijo y estable para el aprendizaje.

# %%
memory = SequentialMemory(limit=50000, window_length=WINDOW_LENGTH)
processor = AcrobotProcessor()

# %%
policy = LinearAnnealedPolicy(EpsGreedyQPolicy(), attr='eps',
                              value_max=0.01, value_min=.05, value_test=.05,
                              nb_steps=30000)

# %%
dqn_1 = DQNAgent(model=model, nb_actions=nb_actions, policy=policy,
                 memory=memory, processor=processor,
                 nb_steps_warmup=1000, gamma=.99,
                 target_model_update=10000,
                 train_interval=4)
dqn_1.compile(Adam(learning_rate=1e-4), metrics=['mae'])

# %%
from tensorflow.keras.callbacks import Callback
# ==========================================
# 4. CALLBACK CON MEMORIA PERSISTENTE
# ==========================================
class SaveBestModel(Callback):
    def __init__(self, filepath):
        super(SaveBestModel, self).__init__()
        self.filepath = filepath
        # Creamos la ruta para el archivo de texto que guardará el puntaje
        self.score_path = filepath.replace('.h5f', '_score.txt')

        # LÓGICA DE REANUDACIÓN DE PUNTAJE
        if os.path.exists(self.score_path):
            with open(self.score_path, 'r') as f:
                self.best_mean_reward = float(f.read())
            print(f"📈 [Memoria] Récord histórico detectado en local. Umbral a superar: {self.best_mean_reward:.2f}")
        else:
            self.best_mean_reward = -500.0
            print("🆕 [Memoria] Primer entrenamiento. Umbral inicial: -500.00")

        self.reward_history = deque(maxlen=20)

    def on_episode_end(self, episode, logs={}):
        self.reward_history.append(logs.get('episode_reward', -500.0))

        if len(self.reward_history) == 20:
            mean_reward = np.mean(self.reward_history)

            if mean_reward > self.best_mean_reward:
                self.best_mean_reward = mean_reward

                # 1. Guardamos los pesos matemáticos
                self.model.save_weights(self.filepath, overwrite=True)

                # 2. Guardamos el nuevo récord en el archivo de texto
                with open(self.score_path, 'w') as f:
                    f.write(str(mean_reward))

                print(f"\n[🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: {mean_reward:.2f}")

# %%
import glob
import os
import json
from collections import deque

# 1. Definimos de qué propuesta se trata para aislar sus archivos
propuesta_id = 'p1'
best_weights_path = os.path.join(drive_root, f'dqn_{env_name}_{propuesta_id}_best.h5f')

# 2. Asignamos nombres únicos a los pesos, checkpoints y logs
weights_filename = os.path.join(drive_root, f'dqn_{env_name}_{propuesta_id}_weights.h5f')
checkpoint_weights_filename = os.path.join(drive_root, f'dqn_{env_name}_{propuesta_id}_weights_{{step}}.h5f')
log_filename = os.path.join(drive_root, f'dqn_{env_name}_{propuesta_id}_log.json')

# 3. LÓGICA DE AUTO-REANUDACIÓN SEGURA
# Ahora el patrón de búsqueda solo filtrará los checkpoints de ESTA propuesta
search_pattern = os.path.join(drive_root, f'dqn_{env_name}_{propuesta_id}_weights_*.h5f.index')
checkpoints = glob.glob(search_pattern)

if checkpoints:
    # Obtenemos el más reciente por fecha de modificación
    latest_checkpoint_index = sorted(checkpoints, key=os.path.getmtime)[-1]
    base_weights_path = latest_checkpoint_index.replace(".index", "")
    print(f"Checkpoint de la {propuesta_id} detectado en local: {base_weights_path}")

    try:
        # ATENCIÓN: Asegúrate de usar la variable correcta de tu agente (ej: dqn_1, dqn_2)
        dqn_1.load_weights(base_weights_path)
        print("¡Pesos cargados correctamente! Reanudando entrenamiento...")
    except Exception as e:
        print(f"Error al cargar pesos: {e}. Se empezará desde cero.")
else:
    print(f"No se encontraron checkpoints previos para la {propuesta_id}. Iniciando desde cero.")


callbacks_1 = [ModelIntervalCheckpoint(checkpoint_weights_filename, interval=10000)]
callbacks_1 += [FileLogger(log_filename, interval=100)]
best_model_path = os.path.join(drive_root, f'dqn_{env_name}_{propuesta_id}_best.h5f')
# 4. Configuración de Callbacks y Entrenamiento
if os.path.exists(best_weights_path + ".index"):
    print(f"Cargando pesos matemáticos previos desde: {best_weights_path}")
    dqn_1.load_weights(best_weights_path)
callbacks_1 += [SaveBestModel(best_model_path)]
# (Recuerda añadir tu callback early_stop aquí si lo vas a usar)

dqn_1.fit(env, callbacks=callbacks_1, nb_steps=80000, log_interval=1000, visualize=False)
dqn_1.save_weights(weights_filename, overwrite=True)
# Out:
# No se encontraron checkpoints previos para la p1. Iniciando desde cero.
# 🆕 [Memoria] Primer entrenamiento. Umbral inicial: -500.00
# Training for 80000 steps ...
# Interval 1 (0 steps performed)
#  221/1000 [=====>........................] - ETA: 0s - reward: -1.0000
# C:\Users\kevin\anaconda3\envs\miar_rl\lib\site-packages\tensorflow\python\keras\engine\training.py:2424: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 1000/1000 [==============================] - 1s 675us/step - reward: -1.0000
# 2 episodes - episode_reward: -500.000 [-500.000, -500.000]
#
# Interval 2 (1000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -1.0000
# 2 episodes - episode_reward: -500.000 [-500.000, -500.000] - loss: 0.212 - mae: 0.314 - mean_q: -0.098 - mean_eps: 0.050
#
# Interval 3 (2000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -1.0000
# 2 episodes - episode_reward: -500.000 [-500.000, -500.000] - loss: 0.005 - mae: 0.555 - mean_q: -0.753 - mean_eps: 0.050
#
# Interval 4 (3000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -0.9990
# 2 episodes - episode_reward: -472.000 [-500.000, -444.000] - loss: 0.002 - mae: 0.602 - mean_q: -0.813 - mean_eps: 0.050
#
# Interval 5 (4000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -0.9960
# 4 episodes - episode_reward: -235.250 [-420.000, -151.000] - loss: 0.002 - mae: 0.587 - mean_q: -0.789 - mean_eps: 0.050
#
# Interval 6 (5000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -0.9950
# 5 episodes - episode_reward: -207.400 [-228.000, -192.000] - loss: 0.002 - mae: 0.569 - mean_q: -0.760 - mean_eps: 0.050
#
# Interval 7 (6000 steps performed)
#  490/1000 [=============>................] - ETA: 1s - reward: -0.9959
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -324.05
#  705/1000 [====================>.........] - ETA: 0s - reward: -0.9957
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -309.90
#  871/1000 [=========================>....] - ETA: 0s - reward: -0.9954
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -293.80
# 1000/1000 [==============================] - 2s 2ms/step - reward: -0.9950
# 5 episodes - episode_reward: -190.800 [-217.000, -178.000] - loss: 0.002 - mae: 0.556 - mean_q: -0.748 - mean_eps: 0.050
#
# Interval 8 (7000 steps performed)
#   42/1000 [>.............................] - ETA: 2s - reward: -1.0000
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -276.80
#  225/1000 [=====>........................] - ETA: 1s - reward: -0.9956
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -261.45
#  494/1000 [=============>................] - ETA: 1s - reward: -0.9960
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -249.10
#  665/1000 [==================>...........] - ETA: 0s - reward: -0.9955
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -232.75
#  845/1000 [========================>.....] - ETA: 0s - reward: -0.9953
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -216.70
# 1000/1000 [==============================] - 2s 2ms/step - reward: -0.9950
# 5 episodes - episode_reward: -191.600 [-253.000, -160.000] - loss: 0.002 - mae: 0.546 - mean_q: -0.740 - mean_eps: 0.050
#
# Interval 9 (8000 steps performed)
#    1/1000 [..............................] - ETA: 5s - reward: -1.0000
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -203.00
#  197/1000 [====>.........................] - ETA: 1s - reward: -0.9949
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -190.85
#  329/1000 [========>.....................] - ETA: 1s - reward: -0.9939
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -188.35
# 1000/1000 [==============================] - 2s 2ms/step - reward: -0.9950
# 5 episodes - episode_reward: -185.200 [-214.000, -152.000] - loss: 0.001 - mae: 0.537 - mean_q: -0.730 - mean_eps: 0.050
#
# Interval 10 (9000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -0.9940
# 6 episodes - episode_reward: -199.667 [-372.000, -114.000] - loss: 0.002 - mae: 0.534 - mean_q: -0.718 - mean_eps: 0.050
#
# Interval 11 (10000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -0.9980
# 2 episodes - episode_reward: -385.000 [-457.000, -313.000] - loss: 0.029 - mae: 1.178 - mean_q: -1.602 - mean_eps: 0.050
#
# Interval 12 (11000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -0.9970
# 3 episodes - episode_reward: -310.000 [-341.000, -276.000] - loss: 0.005 - mae: 1.179 - mean_q: -1.678 - mean_eps: 0.050
#
# Interval 13 (12000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -0.9950
# 5 episodes - episode_reward: -210.800 [-362.000, -120.000] - loss: 0.005 - mae: 1.177 - mean_q: -1.681 - mean_eps: 0.050
#
# Interval 14 (13000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -0.9970
# 4 episodes - episode_reward: -307.250 [-500.000, -202.000] - loss: 0.004 - mae: 1.177 - mean_q: -1.684 - mean_eps: 0.050
#
# Interval 15 (14000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -0.9950
# 5 episodes - episode_reward: -195.400 [-283.000, -154.000] - loss: 0.004 - mae: 1.180 - mean_q: -1.689 - mean_eps: 0.050
#
# Interval 16 (15000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -0.9960
# 4 episodes - episode_reward: -237.750 [-395.000, -143.000] - loss: 0.005 - mae: 1.173 - mean_q: -1.680 - mean_eps: 0.050
#
# Interval 17 (16000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -0.9950
# 5 episodes - episode_reward: -164.400 [-280.000, -105.000] - loss: 0.004 - mae: 1.174 - mean_q: -1.683 - mean_eps: 0.050
#
# Interval 18 (17000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -0.9930
# 7 episodes - episode_reward: -174.714 [-253.000, -135.000] - loss: 0.004 - mae: 1.173 - mean_q: -1.680 - mean_eps: 0.050
#
# Interval 19 (18000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -0.9950
# 5 episodes - episode_reward: -201.000 [-251.000, -159.000] - loss: 0.005 - mae: 1.169 - mean_q: -1.676 - mean_eps: 0.050
#
# Interval 20 (19000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -0.9960
# 4 episodes - episode_reward: -225.000 [-336.000, -129.000] - loss: 0.004 - mae: 1.166 - mean_q: -1.677 - mean_eps: 0.050
#
# Interval 21 (20000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -0.9990
# 2 episodes - episode_reward: -474.000 [-500.000, -448.000] - loss: 0.026 - mae: 1.817 - mean_q: -2.591 - mean_eps: 0.050
#
# Interval 22 (21000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -1.0000
# 2 episodes - episode_reward: -500.000 [-500.000, -500.000] - loss: 0.012 - mae: 1.817 - mean_q: -2.636 - mean_eps: 0.050
#
# Interval 23 (22000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -1.0000
# 2 episodes - episode_reward: -500.000 [-500.000, -500.000] - loss: 0.010 - mae: 1.817 - mean_q: -2.642 - mean_eps: 0.050
#
# Interval 24 (23000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -1.0000
# 2 episodes - episode_reward: -500.000 [-500.000, -500.000] - loss: 0.007 - mae: 1.820 - mean_q: -2.653 - mean_eps: 0.050
#
# Interval 25 (24000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -1.0000
# 2 episodes - episode_reward: -500.000 [-500.000, -500.000] - loss: 0.010 - mae: 1.820 - mean_q: -2.657 - mean_eps: 0.050
#
# Interval 26 (25000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -1.0000
# 2 episodes - episode_reward: -500.000 [-500.000, -500.000] - loss: 0.008 - mae: 1.820 - mean_q: -2.657 - mean_eps: 0.050
#
# Interval 27 (26000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -1.0000
# 2 episodes - episode_reward: -500.000 [-500.000, -500.000] - loss: 0.009 - mae: 1.824 - mean_q: -2.662 - mean_eps: 0.050
#
# Interval 28 (27000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -1.0000
# 2 episodes - episode_reward: -500.000 [-500.000, -500.000] - loss: 0.008 - mae: 1.823 - mean_q: -2.667 - mean_eps: 0.050
#
# Interval 29 (28000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -1.0000
# 2 episodes - episode_reward: -500.000 [-500.000, -500.000] - loss: 0.008 - mae: 1.825 - mean_q: -2.668 - mean_eps: 0.050
#
# Interval 30 (29000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -1.0000
# 2 episodes - episode_reward: -500.000 [-500.000, -500.000] - loss: 0.007 - mae: 1.827 - mean_q: -2.674 - mean_eps: 0.050
#
# Interval 31 (30000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -1.0000
# 2 episodes - episode_reward: -500.000 [-500.000, -500.000] - loss: 0.027 - mae: 2.479 - mean_q: -3.595 - mean_eps: 0.051
#
# Interval 32 (31000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -1.0000
# 2 episodes - episode_reward: -500.000 [-500.000, -500.000] - loss: 0.015 - mae: 2.478 - mean_q: -3.630 - mean_eps: 0.052
#
# Interval 33 (32000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -1.0000
# 2 episodes - episode_reward: -500.000 [-500.000, -500.000] - loss: 0.013 - mae: 2.478 - mean_q: -3.637 - mean_eps: 0.053
#
# Interval 34 (33000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -1.0000
# 2 episodes - episode_reward: -500.000 [-500.000, -500.000] - loss: 0.014 - mae: 2.479 - mean_q: -3.637 - mean_eps: 0.055
#
# Interval 35 (34000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -1.0000
# 2 episodes - episode_reward: -500.000 [-500.000, -500.000] - loss: 0.010 - mae: 2.479 - mean_q: -3.646 - mean_eps: 0.056
#
# Interval 36 (35000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -1.0000
# 2 episodes - episode_reward: -500.000 [-500.000, -500.000] - loss: 0.011 - mae: 2.478 - mean_q: -3.645 - mean_eps: 0.057
#
# Interval 37 (36000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -1.0000
# 2 episodes - episode_reward: -500.000 [-500.000, -500.000] - loss: 0.012 - mae: 2.480 - mean_q: -3.652 - mean_eps: 0.059
#
# Interval 38 (37000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -1.0000
# 2 episodes - episode_reward: -500.000 [-500.000, -500.000] - loss: 0.011 - mae: 2.480 - mean_q: -3.652 - mean_eps: 0.060
#
# Interval 39 (38000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -1.0000
# 2 episodes - episode_reward: -500.000 [-500.000, -500.000] - loss: 0.012 - mae: 2.483 - mean_q: -3.655 - mean_eps: 0.061
#
# Interval 40 (39000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -1.0000
# 2 episodes - episode_reward: -500.000 [-500.000, -500.000] - loss: 0.015 - mae: 2.482 - mean_q: -3.651 - mean_eps: 0.063
#
# Interval 41 (40000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -0.9990
# 2 episodes - episode_reward: -391.000 [-500.000, -282.000] - loss: 0.030 - mae: 3.114 - mean_q: -4.553 - mean_eps: 0.064
#
# Interval 42 (41000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -1.0000
# 2 episodes - episode_reward: -500.000 [-500.000, -500.000] - loss: 0.020 - mae: 3.111 - mean_q: -4.582 - mean_eps: 0.065
#
# Interval 43 (42000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -1.0000
# 2 episodes - episode_reward: -500.000 [-500.000, -500.000] - loss: 0.019 - mae: 3.109 - mean_q: -4.585 - mean_eps: 0.067
#
# Interval 44 (43000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -1.0000
# 2 episodes - episode_reward: -500.000 [-500.000, -500.000] - loss: 0.018 - mae: 3.108 - mean_q: -4.583 - mean_eps: 0.068
#
# Interval 45 (44000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -1.0000
# 2 episodes - episode_reward: -500.000 [-500.000, -500.000] - loss: 0.025 - mae: 3.105 - mean_q: -4.578 - mean_eps: 0.069
#
# Interval 46 (45000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -1.0000
# 2 episodes - episode_reward: -500.000 [-500.000, -500.000] - loss: 0.020 - mae: 3.112 - mean_q: -4.590 - mean_eps: 0.071
#
# Interval 47 (46000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -1.0000
# 2 episodes - episode_reward: -500.000 [-500.000, -500.000] - loss: 0.017 - mae: 3.110 - mean_q: -4.591 - mean_eps: 0.072
#
# Interval 48 (47000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -1.0000
# 2 episodes - episode_reward: -500.000 [-500.000, -500.000] - loss: 0.019 - mae: 3.108 - mean_q: -4.591 - mean_eps: 0.073
#
# Interval 49 (48000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -1.0000
# 2 episodes - episode_reward: -500.000 [-500.000, -500.000] - loss: 0.020 - mae: 3.110 - mean_q: -4.593 - mean_eps: 0.075
#
# Interval 50 (49000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -1.0000
# 2 episodes - episode_reward: -500.000 [-500.000, -500.000] - loss: 0.019 - mae: 3.107 - mean_q: -4.592 - mean_eps: 0.076
#
# Interval 51 (50000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -1.0000
# 2 episodes - episode_reward: -500.000 [-500.000, -500.000] - loss: 0.039 - mae: 3.740 - mean_q: -5.495 - mean_eps: 0.077
#
# Interval 52 (51000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -0.9990
# 2 episodes - episode_reward: -492.000 [-500.000, -484.000] - loss: 0.029 - mae: 3.736 - mean_q: -5.520 - mean_eps: 0.079
#
# Interval 53 (52000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -1.0000
# 2 episodes - episode_reward: -500.000 [-500.000, -500.000] - loss: 0.041 - mae: 3.733 - mean_q: -5.510 - mean_eps: 0.080
#
# Interval 54 (53000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -1.0000
# 2 episodes - episode_reward: -500.000 [-500.000, -500.000] - loss: 0.027 - mae: 3.734 - mean_q: -5.519 - mean_eps: 0.081
#
# Interval 55 (54000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -0.9990
# 2 episodes - episode_reward: -463.500 [-500.000, -427.000] - loss: 0.031 - mae: 3.731 - mean_q: -5.515 - mean_eps: 0.083
#
# Interval 56 (55000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -0.9990
# 3 episodes - episode_reward: -433.000 [-500.000, -299.000] - loss: 0.020 - mae: 3.734 - mean_q: -5.525 - mean_eps: 0.084
#
# Interval 57 (56000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -0.9990
# 2 episodes - episode_reward: -419.000 [-500.000, -338.000] - loss: 0.017 - mae: 3.732 - mean_q: -5.523 - mean_eps: 0.085
#
# Interval 58 (57000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -1.0000
# 2 episodes - episode_reward: -500.000 [-500.000, -500.000] - loss: 0.017 - mae: 3.734 - mean_q: -5.529 - mean_eps: 0.087
#
# Interval 59 (58000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -0.9980
# 3 episodes - episode_reward: -392.333 [-500.000, -233.000] - loss: 0.029 - mae: 3.733 - mean_q: -5.527 - mean_eps: 0.088
#
# Interval 60 (59000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -0.9980
# 2 episodes - episode_reward: -392.000 [-464.000, -320.000] - loss: 0.021 - mae: 3.735 - mean_q: -5.532 - mean_eps: 0.089
#
# Interval 61 (60000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -0.9960
# 4 episodes - episode_reward: -331.000 [-363.000, -287.000] - loss: 0.050 - mae: 4.358 - mean_q: -6.424 - mean_eps: 0.091
#
# Interval 62 (61000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -0.9980
# 2 episodes - episode_reward: -327.500 [-368.000, -287.000] - loss: 0.041 - mae: 4.355 - mean_q: -6.440 - mean_eps: 0.092
#
# Interval 63 (62000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -0.9970
# 3 episodes - episode_reward: -446.667 [-471.000, -403.000] - loss: 0.034 - mae: 4.348 - mean_q: -6.437 - mean_eps: 0.093
#
# Interval 64 (63000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -0.9990
# 2 episodes - episode_reward: -413.000 [-500.000, -326.000] - loss: 0.046 - mae: 4.351 - mean_q: -6.437 - mean_eps: 0.095
#
# Interval 65 (64000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -1.0000
# 2 episodes - episode_reward: -500.000 [-500.000, -500.000] - loss: 0.039 - mae: 4.348 - mean_q: -6.439 - mean_eps: 0.096
#
# Interval 66 (65000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -0.9970
# 3 episodes - episode_reward: -315.333 [-386.000, -258.000] - loss: 0.039 - mae: 4.350 - mean_q: -6.440 - mean_eps: 0.097
#
# Interval 67 (66000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -0.9970
# 3 episodes - episode_reward: -385.000 [-471.000, -274.000] - loss: 0.026 - mae: 4.349 - mean_q: -6.448 - mean_eps: 0.099
#
# Interval 68 (67000 steps performed)
# 1000/1000 [==============================] - 3s 3ms/step - reward: -0.9970
# 4 episodes - episode_reward: -272.000 [-500.000, -149.000] - loss: 0.040 - mae: 4.350 - mean_q: -6.444 - mean_eps: 0.100
#
# Interval 69 (68000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -0.9970
# 3 episodes - episode_reward: -278.667 [-350.000, -231.000] - loss: 0.049 - mae: 4.347 - mean_q: -6.435 - mean_eps: 0.101
#
# Interval 70 (69000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -0.9970
# 3 episodes - episode_reward: -287.333 [-431.000, -193.000] - loss: 0.045 - mae: 4.348 - mean_q: -6.436 - mean_eps: 0.103
#
# Interval 71 (70000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -0.9970
# 4 episodes - episode_reward: -265.250 [-500.000, -185.000] - loss: 0.068 - mae: 4.925 - mean_q: -7.269 - mean_eps: 0.104
#
# Interval 72 (71000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -0.9960
# 4 episodes - episode_reward: -306.250 [-428.000, -132.000] - loss: 0.043 - mae: 4.920 - mean_q: -7.286 - mean_eps: 0.105
#
# Interval 73 (72000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -0.9990
# 2 episodes - episode_reward: -325.000 [-500.000, -150.000] - loss: 0.051 - mae: 4.915 - mean_q: -7.274 - mean_eps: 0.107
#
# Interval 74 (73000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -0.9990
# 3 episodes - episode_reward: -402.333 [-500.000, -207.000] - loss: 0.060 - mae: 4.910 - mean_q: -7.265 - mean_eps: 0.108
#
# Interval 75 (74000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -0.9960
# 4 episodes - episode_reward: -267.250 [-418.000, -160.000] - loss: 0.049 - mae: 4.911 - mean_q: -7.267 - mean_eps: 0.109
#
# Interval 76 (75000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -0.9970
# 3 episodes - episode_reward: -289.333 [-393.000, -203.000] - loss: 0.044 - mae: 4.915 - mean_q: -7.268 - mean_eps: 0.111
#
# Interval 77 (76000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -0.9970
# 3 episodes - episode_reward: -320.000 [-474.000, -229.000] - loss: 0.059 - mae: 4.910 - mean_q: -7.258 - mean_eps: 0.112
#
# Interval 78 (77000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -0.9970
# 3 episodes - episode_reward: -387.333 [-465.000, -341.000] - loss: 0.057 - mae: 4.907 - mean_q: -7.248 - mean_eps: 0.113
#
# Interval 79 (78000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -1.0000
# 2 episodes - episode_reward: -500.000 [-500.000, -500.000] - loss: 0.046 - mae: 4.905 - mean_q: -7.251 - mean_eps: 0.115
#
# Interval 80 (79000 steps performed)
# 1000/1000 [==============================] - 2s 2ms/step - reward: -1.0000
# done, took 168.575 seconds

# %%
import numpy as np
import pandas as pd
from rl.policy import EpsGreedyQPolicy

# 1. Le decimos a tu agente original que use 1% de exploración en el test
# dqn_1.test_policy = EpsGreedyQPolicy(eps=0.01)
propuesta_id = 'p1'
best_weights_path = os.path.join(drive_root, f'dqn_{env_name}_{propuesta_id}_best.h5f')

print(f"🧠 Intentando cargar el cerebro maestro en dqn_1 desde:\n{best_weights_path}\n")

try:
    # 2. Inyectamos los pesos en el agente original
    dqn_1.load_weights(best_weights_path)
    print("✅ ¡Carga exitosa! El agente dqn_1 ha recuperado su nivel experto.")

    # 3. Ejecutamos la evaluación en silencio
    print("\nIniciando evaluación de 100 episodios... ¡Paciencia!")
    history = dqn_1.test(env, nb_episodes=100, visualize=False, verbose=0)

    # 4. Resultados reales
    test_rewards = history.history['episode_reward']
    mean_reward = np.mean(history.history['episode_reward'])
    print("\n" + "⭐"*20)
    print(f"🏆 MEDIA FINAL DE TU PROYECTO: {mean_reward:.2f}")
    print("⭐"*20)

except Exception as e:
    # Si falla, esta vez sí imprimirá el error exacto en rojo para que sepamos qué es
    print("\n❌ ERROR REAL AL CARGAR EL ARCHIVO:")
    print(e)
# Out:
# 🧠 Intentando cargar el cerebro maestro en dqn_1 desde:
# C:\Users\kevin\Downloads\ESTUDIO MASTER EN IA\Aprendizaje por refuerzo\PROYECTO\Proyecto RL\dqn_Acrobot-v1_p1_best.h5f
#
# ✅ ¡Carga exitosa! El agente dqn_1 ha recuperado su nivel experto.
#
# Iniciando evaluación de 100 episodios... ¡Paciencia!
#
# ⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐
# 🏆 MEDIA FINAL DE TU PROYECTO: -177.53
# ⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐⭐

# %%
# !pip install pyvirtualdisplay
# Out:
# Collecting pyvirtualdisplay
#   Downloading PyVirtualDisplay-3.0-py3-none-any.whl.metadata (943 bytes)
# Downloading PyVirtualDisplay-3.0-py3-none-any.whl (15 kB)
# Installing collected packages: pyvirtualdisplay
# Successfully installed pyvirtualdisplay-3.0

# %%
import shutil

ruta_ffmpeg = r"C:\Users\kevin\anaconda3\envs\miar_rl\Library\bin"

os.environ["PATH"] = ruta_ffmpeg + os.pathsep + os.environ["PATH"]

print("ffmpeg detectado:", shutil.which("ffmpeg"))
# Out:
# ffmpeg detectado: C:\Users\kevin\anaconda3\envs\miar_rl\Library\bin\ffmpeg.EXE

# %%
import gym
from gym.wrappers import Monitor
from rl.policy import EpsGreedyQPolicy

# ==========================================
# 1. PREPARAR LA CÁMARA
# ==========================================
# Creamos un entorno fresco exclusivo para el video
env_video = gym.make('Acrobot-v1')
carpeta_videos = './videos_proyecto'
env_video = Monitor(env_video, carpeta_videos, force=True, video_callable=lambda episode_id: True)

# ==========================================
# 2. PREPARAR AL AGENTE QUE YA TIENES EN MEMORIA
# ==========================================
# Le quitamos la aleatoriedad para que use lo que ya aprendió
dqn_1.test_policy = EpsGreedyQPolicy(eps=0.0)

# ==========================================
# 3. ¡GRABACIÓN SILENCIOSA!
# ==========================================
print(f"🎬 Grabando 3 episodios... (Renderizando en segundo plano)")

# IMPORTANTE: visualize=False es obligatorio en WSL
dqn_1.test(env_video, nb_episodes=3, visualize=False, verbose=1)

# ==========================================
# 4. APAGAR Y GUARDAR
# ==========================================
env_video.close()

print("\n✅ ¡Corte! Video guardado exitosamente en la carpeta 'videos_proyecto'.")
# Out:
# 🎬 Grabando 3 episodios... (Renderizando en segundo plano)
# Testing for 3 episodes ...
# Episode 1: reward: -160.000, steps: 161
# Episode 2: reward: -166.000, steps: 167
# Episode 3: reward: -144.000, steps: 145
#
# ✅ ¡Corte! Video guardado exitosamente en la carpeta 'videos_proyecto'.

# %%
## 3.1. Cargar log de entrenamiento
log_path = os.path.join(drive_root, f'dqn_{env_name}_{propuesta_id}_log.json')

with open(log_path, 'r') as f:
    log_data = json.load(f)

episode_reward = log_data['episode_reward']
nb_episode_steps = log_data['nb_episode_steps']
nb_steps = log_data['nb_steps']

print("Número de episodios registrados:", len(episode_reward))
print("Último paso registrado:", nb_steps[-1])
print("Recompensa media entrenamiento:", np.mean(episode_reward))
print("Mejor recompensa:", np.max(episode_reward))
print("Peor recompensa:", np.min(episode_reward))
# Out:
# Número de episodios registrados: 223
# Último paso registrado: 79923
# Recompensa media entrenamiento: -357.8116591928251
# Mejor recompensa: -105.0
# Peor recompensa: -500.0

# %% [markdown]
# De los 223 episodios registrados en los 79 923 pasos de entrenamiento, la recompensa media (-357.81) se sitúa en un punto intermedio, alejada tanto del peor valor posible (-500) como de un desempeño consistente, lo que indica que, si bien la mayoría de los episodios no logra resolver el entorno de forma completa, una parte considerable de ellos consigue terminar antes de agotar el límite de pasos. El mejor episodio registrado (-105.0) confirma que el agente llegó a ejecutar en varias ocasiones una secuencia de acciones eficiente, cercana a un comportamiento exitoso. Aun así, el hecho de que el peor valor siga siendo -500 muestra que el agente todavía no logra consolidar ese aprendizaje de forma estable y consistente a lo largo de todo el entrenamiento.

# %%
#3.2. Gráfica 1 — Recompensa por episodio
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 5))
plt.plot(episode_reward)
plt.title('Propuesta base - Recompensa por episodio')
plt.xlabel('Episodio')
plt.ylabel('Recompensa')
plt.grid(True)
plt.show()

# %% [markdown]
# Se observa una fase inicial de fallo total, con varios episodios consecutivos en -500 antes de que el agente empiece a mostrar mejoras. A partir de ahí, la recompensa oscila con fuerza entre valores intermedios (-100 a -300) y nuevas caídas a -500, incluso en tramos avanzados del entrenamiento (episodios ~100-150 y ~200-220). Esto confirma una alta variabilidad: el agente logra mejorar, pero no de forma monótona ni estable.

# %%
# 3.3. Gráfica 2 — Media móvil de recompensa
window = 20
moving_avg_reward = pd.Series(episode_reward).rolling(window).mean()

plt.figure(figsize=(12, 5))
plt.plot(moving_avg_reward)
plt.title(f'Propuesta base - Media móvil de recompensa ({window} episodios)')
plt.xlabel('Episodio')
plt.ylabel('Recompensa media')
plt.grid(True)
plt.show()

# %% [markdown]
# La curva muestra una mejora clara en la primera mitad del entrenamiento, alcanzando su mejor punto (cercano a -190) alrededor del episodio 30-75. Sin embargo, después cae de forma pronunciada hasta tocar de nuevo el fondo de -500 cerca del episodio 100-120, y solo hacia el final del entrenamiento vuelve a recuperarse parcialmente, sin llegar a alcanzar el nivel de su mejor tramo anterior. Es una curva de aprendizaje inestable, con retrocesos importantes.

# %%
plt.figure(figsize=(12, 5))
plt.plot(test_rewards, marker='o')
plt.title('Propuesta base - Recompensa en 100 episodios de test')
plt.xlabel('Episodio de test')
plt.ylabel('Recompensa')
plt.grid(True)
plt.show()

# %% [markdown]
#  La evaluación muestra en su mayoría episodios con recompensas razonablemente buenas (entre -100 y -250), lo que indica que la política aprendida es capaz de resolver el entorno en la mayoría de los casos. Aun así, aparece al menos un episodio con fallo total (-500), lo que confirma que el comportamiento, aunque mayormente funcional, no es completamente fiable.

# %% [markdown]
# ## 3. Justificación de los parámetros seleccionados y de los resultados obtenidos
#
# La propuesta base se diseñó como primera aproximación al entorno Acrobot-v1 utilizando el algoritmo DQN, adecuado dado que el espacio de acciones es discreto: el agente debe elegir entre tres acciones relacionadas con el torque aplicado sobre la articulación actuada.
#
# En coherencia con esta elección, el resto de parámetros se definió según las características del problema. Al tratarse de un vector de observación numérico y no de imágenes, se usó una red densa de tres capas ocultas de 64 neuronas (ReLU) y una capa de salida lineal con tantas neuronas como acciones, encargada de aproximar los valores Q a partir del estado observado. Para estabilizar el entrenamiento, se incorporó una memoria de repetición de 50 000 transiciones con ventana temporal de longitud 1, que reduce la dependencia entre muestras consecutivas y mitiga la correlación entre observaciones sucesivas.
#
# En cuanto a la exploración, se optó por una estrategia epsilon-greedy con valores bajos, priorizando la acción óptima frente a la aleatoria. Esta configuración, sencilla como punto de partida, ayuda a explicar las limitaciones observadas más adelante: en un entorno como Acrobot-v1, donde se requieren movimientos de balanceo coordinados para aprovechar la inercia del sistema, una exploración reducida dificulta que el agente descubra trayectorias útiles de forma consistente.
#
# El entrenamiento se ejecutó durante 80 000 pasos, con callbacks para guardar checkpoints, registrar logs y conservar los mejores pesos, lo que permitió analizar la evolución del agente. Los resultados muestran un aprendizaje real pero inestable: la recompensa media de entrenamiento fue de -357.81, con episodios que llegaron a alcanzar hasta -105, evidencia de que el agente encontró en varias ocasiones secuencias de acciones eficientes. Sin embargo, la persistencia de episodios con recompensa -500 en distintos tramos del entrenamiento —incluso después de haber mostrado mejoras notables— indica que ese aprendizaje no logra consolidarse de forma sostenida. En test, con 100 episodios evaluados, la media final fue de -177.53, lo que confirma que la política aprendida resuelve el entorno en la mayoría de los casos, aunque conserva episodios ocasionales de fallo total, mostrando que el comportamiento aún no es completamente fiable.
#
# En conjunto, estos resultados muestran que la exploración limitada, junto con la dificultad intrínseca del entorno, restringe la capacidad del agente para descubrir y mantener de forma consistente la secuencia de acciones necesaria para resolver la tarea. Aun así, la propuesta base cumple su función: valida correctamente la implementación del entorno, del agente y del proceso de guardado de pesos, y sirve como punto de comparación para las propuestas de mejora posteriores.

# %% [markdown]
# ## 4. Propuesta de mejora 1: Exploración progresiva con epsilon decreciente.
#
# A partir de los resultados obtenidos en la propuesta base, se observa que el agente DQN no consigue resolver de forma estable el entorno `Acrobot-v1`. La recompensa media se mantiene cercana a `-500`, lo que indica que en la mayoría de episodios el agente alcanza el límite máximo de pasos sin llegar al objetivo.
#
# Una posible causa de este bajo rendimiento es una exploración insuficiente durante el entrenamiento. En `Acrobot-v1`, el agente debe aprender a coordinar movimientos de balanceo para aprovechar la inercia del sistema y alcanzar la altura objetivo. Este comportamiento no suele descubrirse fácilmente si el agente explora poco desde el inicio.
#
# Por este motivo, en esta primera propuesta de mejora se modifica la política de exploración del agente. En lugar de utilizar una exploración baja o poco variable, se emplea una política `epsilon-greedy` con reducción progresiva de epsilon. De esta forma, el agente comienza el entrenamiento con alta exploración y, a medida que avanza el aprendizaje, reduce gradualmente la aleatoriedad para explotar las acciones que considera más favorables.
#
# La hipótesis de esta propuesta es que una mayor exploración inicial permitirá al agente descubrir trayectorias más útiles y mejorar la recompensa media obtenida durante el entrenamiento y la fase de test.

# %%
# Entorno
env_name = "Acrobot-v1"
env_p2 = gym.make(env_name)

# Semilla para hacer el experimento algo más reproducible
np.random.seed(123)
env_p2.seed(123)

# Información del entorno
nb_actions = env_p2.action_space.n
obs_shape = env_p2.observation_space.shape

print("Entorno:", env_name)
print("Número de acciones:", nb_actions)
print("Forma de observación:", obs_shape)

# Identificador interno de la propuesta
propuesta_id = "p2"

best_weights_path_p2 = os.path.join(drive_root, f'dqn_{env_name}_{propuesta_id}_best.h5f')
weights_filename_p2 = os.path.join(drive_root, f'dqn_{env_name}_{propuesta_id}_weights.h5f')
checkpoint_weights_filename_p2 = os.path.join(drive_root, f'dqn_{env_name}_{propuesta_id}_weights_{{step}}.h5f')
log_filename_p2 = os.path.join(drive_root, f'dqn_{env_name}_{propuesta_id}_log.json')
# Out:
# Entorno: Acrobot-v1
# Número de acciones: 3
# Forma de observación: (6,)

# %%
model_p2 = Sequential()
model_p2.add(Flatten(input_shape=(1,) + obs_shape))
model_p2.add(Dense(64, activation='relu'))
model_p2.add(Dense(64, activation='relu'))
model_p2.add(Dense(64, activation='relu'))
model_p2.add(Dense(nb_actions, activation='linear'))

model_p2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 6)                 0
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                448
# _________________________________________________________________
# dense_5 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_6 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_7 (Dense)              (None, 3)                 195
# =================================================================
# Total params: 8,963
# Trainable params: 8,963
# Non-trainable params: 0
# _________________________________________________________________

# %%
memory_p2 = SequentialMemory(
    limit=50000,
    window_length=1
)

policy_p2 = LinearAnnealedPolicy(
    EpsGreedyQPolicy(),
    attr='eps',
    value_max=1.0,
    value_min=0.05,
    value_test=0.0,
    nb_steps=60000
)

# %%
# Se crea el agente DQN de la propuesta p2.
# Esta propuesta mantiene la misma red, memoria y parámetros principales de la base,
# pero cambia la política de exploración por una estrategia epsilon-greedy decreciente.

dqn_p2 = DQNAgent(model=model_p2, nb_actions=nb_actions, memory=memory_p2, nb_steps_warmup=1000, target_model_update=1e-2,
                  policy=policy_p2, enable_double_dqn=False)

dqn_p2.compile(Adam(learning_rate=1e-3), metrics=['mae'])

# %%
search_pattern = os.path.join(
    drive_root,
    f'dqn_{env_name}_{propuesta_id}_weights_*.h5f.index'
)

checkpoints = glob.glob(search_pattern)

if checkpoints:
    latest_checkpoint_index = sorted(checkpoints, key=os.path.getmtime)[-1]
    base_weights_path = latest_checkpoint_index.replace(".index", "")

    print("Checkpoint detectado:")
    print(base_weights_path)

    try:
        dqn_p2.load_weights(base_weights_path)
        print("Pesos cargados correctamente. Reanudando entrenamiento.")
    except Exception as e:
        print("Error al cargar pesos:", e)
        print("Se empezará desde cero.")
else:
    print("No se encontraron checkpoints previos para p2. Iniciando desde cero.")
# Out:
# No se encontraron checkpoints previos para p2. Iniciando desde cero.

# %%
callbacks_p2 = [
    ModelIntervalCheckpoint(checkpoint_weights_filename_p2, interval=10000),
    FileLogger(log_filename_p2, interval=1000)
]

callbacks_p2 += [SaveBestModel(best_weights_path_p2)]
# Out:
# 🆕 [Memoria] Primer entrenamiento. Umbral inicial: -500.00

# %%
history_p2 = dqn_p2.fit(
    env_p2,
    callbacks=callbacks_p2,
    nb_steps=80000,
    log_interval=1000,
    visualize=False
)
# Out:
# Training for 80000 steps ...
# Interval 1 (0 steps performed)
#  146/1000 [===>..........................] - ETA: 0s - reward: -1.0000
# C:\Users\kevin\anaconda3\envs\miar_rl\lib\site-packages\tensorflow\python\keras\engine\training.py:2424: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 1000/1000 [==============================] - 1s 779us/step - reward: -1.0000
# 2 episodes - episode_reward: -500.000 [-500.000, -500.000]
#
# Interval 2 (1000 steps performed)
# 1000/1000 [==============================] - 6s 6ms/step - reward: -1.0000
# 2 episodes - episode_reward: -500.000 [-500.000, -500.000] - loss: 0.024 - mae: 3.092 - mean_q: -4.519 - mean_eps: 0.976
#
# Interval 3 (2000 steps performed)
# 1000/1000 [==============================] - 6s 6ms/step - reward: -1.0000
# 2 episodes - episode_reward: -500.000 [-500.000, -500.000] - loss: 0.135 - mae: 8.363 - mean_q: -12.306 - mean_eps: 0.960
#
# Interval 4 (3000 steps performed)
# 1000/1000 [==============================] - 6s 6ms/step - reward: -1.0000
# 2 episodes - episode_reward: -500.000 [-500.000, -500.000] - loss: 0.232 - mae: 13.087 - mean_q: -19.319 - mean_eps: 0.945
#
# Interval 5 (4000 steps performed)
# 1000/1000 [==============================] - 6s 6ms/step - reward: -1.0000
# 2 episodes - episode_reward: -500.000 [-500.000, -500.000] - loss: 0.425 - mae: 16.885 - mean_q: -24.871 - mean_eps: 0.929
#
# Interval 6 (5000 steps performed)
# 1000/1000 [==============================] - 6s 6ms/step - reward: -0.9990
# 2 episodes - episode_reward: -482.000 [-500.000, -464.000] - loss: 0.596 - mae: 19.123 - mean_q: -28.046 - mean_eps: 0.913
#
# Interval 7 (6000 steps performed)
# 1000/1000 [==============================] - 6s 6ms/step - reward: -0.9990
# 2 episodes - episode_reward: -466.500 [-500.000, -433.000] - loss: 0.609 - mae: 20.471 - mean_q: -29.992 - mean_eps: 0.897
#
# Interval 8 (7000 steps performed)
# 1000/1000 [==============================] - 6s 6ms/step - reward: -1.0000
# 2 episodes - episode_reward: -500.000 [-500.000, -500.000] - loss: 0.725 - mae: 21.303 - mean_q: -31.155 - mean_eps: 0.881
#
# Interval 9 (8000 steps performed)
# 1000/1000 [==============================] - 6s 6ms/step - reward: -0.9970
# 3 episodes - episode_reward: -331.000 [-421.000, -274.000] - loss: 0.625 - mae: 21.727 - mean_q: -31.772 - mean_eps: 0.865
#
# Interval 10 (9000 steps performed)
#  388/1000 [==========>...................] - ETA: 3s - reward: -1.0000
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -469.50
# 1000/1000 [==============================] - 6s 6ms/step - reward: -1.0000
# 2 episodes - episode_reward: -500.000 [-500.000, -500.000] - loss: 0.793 - mae: 21.826 - mean_q: -31.869 - mean_eps: 0.850
#
# Interval 11 (10000 steps performed)
#  790/1000 [======================>.......] - ETA: 1s - reward: -0.9987
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -464.20
# 1000/1000 [==============================] - 6s 6ms/step - reward: -0.9990
# 2 episodes - episode_reward: -447.000 [-500.000, -394.000] - loss: 0.713 - mae: 22.167 - mean_q: -32.410 - mean_eps: 0.834
#
# Interval 12 (11000 steps performed)
#  141/1000 [===>..........................] - ETA: 5s - reward: -0.9929
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -456.70
#  836/1000 [========================>.....] - ETA: 1s - reward: -0.9988
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -441.50
# 1000/1000 [==============================] - 6s 6ms/step - reward: -0.9980
# 3 episodes - episode_reward: -348.667 [-500.000, -196.000] - loss: 0.808 - mae: 22.638 - mean_q: -33.119 - mean_eps: 0.818
#
# Interval 13 (12000 steps performed)
#  169/1000 [====>.........................] - ETA: 4s - reward: -1.0000
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -433.15
#  414/1000 [===========>..................] - ETA: 3s - reward: -0.9952
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -420.20
#  797/1000 [======================>.......] - ETA: 1s - reward: -0.9975
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -414.55
# 1000/1000 [==============================] - 6s 6ms/step - reward: -0.9970
# 3 episodes - episode_reward: -320.333 [-387.000, -241.000] - loss: 0.805 - mae: 23.136 - mean_q: -33.904 - mean_eps: 0.802
#
# Interval 14 (13000 steps performed)
#   53/1000 [>.............................] - ETA: 5s - reward: -1.0000
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -402.20
#  424/1000 [===========>..................] - ETA: 3s - reward: -0.9976
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -397.55
# 1000/1000 [==============================] - 6s 6ms/step - reward: -0.9980
# 3 episodes - episode_reward: -374.667 [-500.000, -253.000] - loss: 0.870 - mae: 23.759 - mean_q: -34.817 - mean_eps: 0.786
#
# Interval 15 (14000 steps performed)
#  286/1000 [=======>......................] - ETA: 4s - reward: -1.0000
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -393.80
#  575/1000 [================>.............] - ETA: 2s - reward: -0.9983
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -383.35
#  849/1000 [========================>.....] - ETA: 0s - reward: -0.9965
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -371.80
# 1000/1000 [==============================] - 6s 6ms/step - reward: -0.9970
# 3 episodes - episode_reward: -306.000 [-358.000, -269.000] - loss: 0.750 - mae: 24.302 - mean_q: -35.629 - mean_eps: 0.770
#
# Interval 16 (15000 steps performed)
#  233/1000 [=====>........................] - ETA: 4s - reward: -1.0000
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -366.00
#  414/1000 [===========>..................] - ETA: 3s - reward: -0.9976
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -361.45
# 1000/1000 [==============================] - 6s 6ms/step - reward: -0.9970
# 3 episodes - episode_reward: -305.000 [-384.000, -183.000] - loss: 0.884 - mae: 24.757 - mean_q: -36.282 - mean_eps: 0.755
#
# Interval 17 (16000 steps performed)
#   83/1000 [=>............................] - ETA: 5s - reward: -1.0000
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -359.05
#  298/1000 [=======>......................] - ETA: 4s - reward: -0.9966
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -344.40
#  606/1000 [=================>............] - ETA: 2s - reward: -0.9967
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -335.05
#  841/1000 [========================>.....] - ETA: 1s - reward: -0.9964
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -321.70
# 1000/1000 [==============================] - 6s 6ms/step - reward: -0.9960
# 4 episodes - episode_reward: -269.000 [-323.000, -207.000] - loss: 0.852 - mae: 25.136 - mean_q: -36.843 - mean_eps: 0.739
#
# Interval 18 (17000 steps performed)
#  123/1000 [==>...........................] - ETA: 5s - reward: -1.0000
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -315.85
#  719/1000 [====================>.........] - ETA: 1s - reward: -0.9958
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -302.95
# 1000/1000 [==============================] - 6s 6ms/step - reward: -0.9960
# 4 episodes - episode_reward: -275.000 [-357.000, -231.000] - loss: 0.744 - mae: 25.516 - mean_q: -37.411 - mean_eps: 0.723
#
# Interval 19 (18000 steps performed)
#  179/1000 [====>.........................] - ETA: 4s - reward: -0.9944
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -299.40
#  404/1000 [===========>..................] - ETA: 3s - reward: -0.9975
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -298.80
# 1000/1000 [==============================] - 6s 6ms/step - reward: -0.9980
# 3 episodes - episode_reward: -318.667 [-500.000, -227.000] - loss: 0.745 - mae: 25.736 - mean_q: -37.725 - mean_eps: 0.707
#
# Interval 20 (19000 steps performed)
#  348/1000 [=========>....................] - ETA: 4s - reward: -0.9971
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -295.20
#  573/1000 [================>.............] - ETA: 2s - reward: -0.9965
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -281.60
#  873/1000 [=========================>....] - ETA: 0s - reward: -0.9966
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -278.65
# 1000/1000 [==============================] - 6s 6ms/step - reward: -0.9960
# 4 episodes - episode_reward: -241.500 [-299.000, -217.000] - loss: 0.842 - mae: 25.761 - mean_q: -37.720 - mean_eps: 0.691
#
# Interval 21 (20000 steps performed)
#   41/1000 [>.............................] - ETA: 6s - reward: -1.0000
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -272.45
#  176/1000 [====>.........................] - ETA: 5s - reward: -0.9943
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -265.60
#  448/1000 [============>.................] - ETA: 3s - reward: -0.9955
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -260.05
# 1000/1000 [==============================] - 6s 6ms/step - reward: -0.9950
# 5 episodes - episode_reward: -222.200 [-309.000, -132.000] - loss: 0.735 - mae: 25.963 - mean_q: -38.041 - mean_eps: 0.675
#
# Interval 22 (21000 steps performed)
#  172/1000 [====>.........................] - ETA: 4s - reward: -1.0000
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -253.50
#  379/1000 [==========>...................] - ETA: 3s - reward: -0.9974
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -253.25
#  612/1000 [=================>............] - ETA: 2s - reward: -0.9967
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -249.10
# 1000/1000 [==============================] - 6s 6ms/step - reward: -0.9960
# 4 episodes - episode_reward: -227.500 [-294.000, -184.000] - loss: 0.717 - mae: 25.941 - mean_q: -38.013 - mean_eps: 0.660
#
# Interval 23 (22000 steps performed)
#  349/1000 [=========>....................] - ETA: 3s - reward: -0.9971
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -242.65
#  546/1000 [===============>..............] - ETA: 2s - reward: -0.9963
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -240.55
#  769/1000 [======================>.......] - ETA: 1s - reward: -0.9961
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -240.10
#  986/1000 [============================>.] - ETA: 0s - reward: -0.9959
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -239.50
# 1000/1000 [==============================] - 6s 6ms/step - reward: -0.9950
# 5 episodes - episode_reward: -214.800 [-288.000, -156.000] - loss: 0.988 - mae: 25.974 - mean_q: -38.011 - mean_eps: 0.644
#
# Interval 24 (23000 steps performed)
#  131/1000 [==>...........................] - ETA: 5s - reward: -1.0000
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -235.30
#  353/1000 [=========>....................] - ETA: 4s - reward: -0.9972
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -221.25
#  548/1000 [===============>..............] - ETA: 2s - reward: -0.9964
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -219.90
#  738/1000 [=====================>........] - ETA: 1s - reward: -0.9959
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -218.60
#  894/1000 [=========================>....] - ETA: 0s - reward: -0.9955
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -215.05
# 1000/1000 [==============================] - 6s 6ms/step - reward: -0.9950
# 5 episodes - episode_reward: -181.400 [-219.000, -145.000] - loss: 0.907 - mae: 25.830 - mean_q: -37.787 - mean_eps: 0.628
#
# Interval 25 (24000 steps performed)
#   66/1000 [>.............................] - ETA: 6s - reward: -1.0000
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -208.65
# 1000/1000 [==============================] - 6s 6ms/step - reward: -0.9950
# 5 episodes - episode_reward: -212.200 [-278.000, -171.000] - loss: 0.943 - mae: 25.708 - mean_q: -37.575 - mean_eps: 0.612
#
# Interval 26 (25000 steps performed)
# 1000/1000 [==============================] - 6s 6ms/step - reward: -0.9960
# 4 episodes - episode_reward: -237.500 [-291.000, -191.000] - loss: 0.957 - mae: 25.568 - mean_q: -37.358 - mean_eps: 0.596
#
# Interval 27 (26000 steps performed)
#  270/1000 [=======>......................] - ETA: 4s - reward: -0.9926
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -202.60
# 1000/1000 [==============================] - 6s 6ms/step - reward: -0.9950
# 5 episodes - episode_reward: -204.200 [-269.000, -160.000] - loss: 0.757 - mae: 25.478 - mean_q: -37.256 - mean_eps: 0.580
#
# Interval 28 (27000 steps performed)
#  393/1000 [==========>...................] - ETA: 3s - reward: -0.9949
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -201.10
#  555/1000 [===============>..............] - ETA: 2s - reward: -0.9946
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -199.40
#  713/1000 [====================>.........] - ETA: 1s - reward: -0.9944
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -197.60
# 1000/1000 [==============================] - 6s 6ms/step - reward: -0.9940
# 6 episodes - episode_reward: -153.500 [-178.000, -117.000] - loss: 0.714 - mae: 25.321 - mean_q: -37.004 - mean_eps: 0.565
#
# Interval 29 (28000 steps performed)
#  434/1000 [============>.................] - ETA: 3s - reward: -0.9954
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -196.25
#  745/1000 [=====================>........] - ETA: 1s - reward: -0.9946
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -188.15
#  899/1000 [=========================>....] - ETA: 0s - reward: -0.9944
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -184.25
# 1000/1000 [==============================] - 6s 6ms/step - reward: -0.9940
# 6 episodes - episode_reward: -170.500 [-275.000, -103.000] - loss: 0.837 - mae: 25.381 - mean_q: -37.064 - mean_eps: 0.549
#
# Interval 30 (29000 steps performed)
#   59/1000 [>.............................] - ETA: 6s - reward: -1.0000
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -177.55
#  203/1000 [=====>........................] - ETA: 5s - reward: -0.9901
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -172.75
#  339/1000 [=========>....................] - ETA: 4s - reward: -0.9941
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -170.10
#  509/1000 [==============>...............] - ETA: 3s - reward: -0.9941
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -169.05
#  624/1000 [=================>............] - ETA: 2s - reward: -0.9936
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -166.95
# 1000/1000 [==============================] - 7s 7ms/step - reward: -0.9940
# 6 episodes - episode_reward: -157.667 [-224.000, -118.000] - loss: 0.805 - mae: 25.182 - mean_q: -36.762 - mean_eps: 0.533
#
# Interval 31 (30000 steps performed)
#   10/1000 [..............................] - ETA: 6s - reward: -1.0000
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -162.50
#  160/1000 [===>..........................] - ETA: 5s - reward: -0.9938
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -160.05
#  582/1000 [================>.............] - ETA: 2s - reward: -0.9931
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -158.40
#  873/1000 [=========================>....] - ETA: 0s - reward: -0.9931
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -157.25
# 1000/1000 [==============================] - 6s 6ms/step - reward: -0.9930
# 7 episodes - episode_reward: -145.429 [-186.000, -107.000] - loss: 0.929 - mae: 25.131 - mean_q: -36.699 - mean_eps: 0.517
#
# Interval 32 (31000 steps performed)
#    1/1000 [..............................] - ETA: 7s - reward: -1.0000
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -155.50
#  108/1000 [==>...........................] - ETA: 5s - reward: -0.9907
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -147.10
# 1000/1000 [==============================] - 6s 6ms/step - reward: -0.9930
# 7 episodes - episode_reward: -147.857 [-200.000, -107.000] - loss: 0.824 - mae: 25.064 - mean_q: -36.586 - mean_eps: 0.501
#
# Interval 33 (32000 steps performed)
#  788/1000 [======================>.......] - ETA: 1s - reward: -0.9937
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -145.85
#  936/1000 [===========================>..] - ETA: 0s - reward: -0.9936
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -145.50
# 1000/1000 [==============================] - 6s 6ms/step - reward: -0.9930
# 7 episodes - episode_reward: -145.000 [-192.000, -114.000] - loss: 0.662 - mae: 24.874 - mean_q: -36.284 - mean_eps: 0.485
#
# Interval 34 (33000 steps performed)
#   79/1000 [=>............................] - ETA: 5s - reward: -1.0000
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -144.80
#  356/1000 [=========>....................] - ETA: 4s - reward: -0.9944
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -144.35
#  647/1000 [==================>...........] - ETA: 2s - reward: -0.9938
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -142.90
# 1000/1000 [==============================] - 6s 6ms/step - reward: -0.9930
# 7 episodes - episode_reward: -148.714 [-225.000, -115.000] - loss: 0.726 - mae: 24.788 - mean_q: -36.150 - mean_eps: 0.470
#
# Interval 35 (34000 steps performed)
# 1000/1000 [==============================] - 6s 6ms/step - reward: -0.9940
# 6 episodes - episode_reward: -148.833 [-197.000, -129.000] - loss: 0.797 - mae: 24.446 - mean_q: -35.613 - mean_eps: 0.454
#
# Interval 36 (35000 steps performed)
#  801/1000 [=======================>......] - ETA: 1s - reward: -0.9913
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -141.90
#  928/1000 [==========================>...] - ETA: 0s - reward: -0.9925
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -141.30
# 1000/1000 [==============================] - 6s 6ms/step - reward: -0.9920
# 8 episodes - episode_reward: -128.875 [-151.000, -111.000] - loss: 0.706 - mae: 24.254 - mean_q: -35.346 - mean_eps: 0.438
#
# Interval 37 (36000 steps performed)
#  967/1000 [============================>.] - ETA: 0s - reward: -0.9938
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -138.05
# 1000/1000 [==============================] - 6s 6ms/step - reward: -0.9930
# 7 episodes - episode_reward: -147.714 [-173.000, -119.000] - loss: 0.656 - mae: 24.159 - mean_q: -35.186 - mean_eps: 0.422
#
# Interval 38 (37000 steps performed)
#  512/1000 [==============>...............] - ETA: 3s - reward: -0.9922
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -137.20
#  636/1000 [==================>...........] - ETA: 2s - reward: -0.9921
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -136.30
#  743/1000 [=====================>........] - ETA: 1s - reward: -0.9933
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -134.65
#  858/1000 [========================>.....] - ETA: 0s - reward: -0.9918
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -133.45
#  959/1000 [===========================>..] - ETA: 0s - reward: -0.9927
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -131.10
# 1000/1000 [==============================] - 7s 7ms/step - reward: -0.9920
# 8 episodes - episode_reward: -123.125 [-161.000, -103.000] - loss: 0.657 - mae: 23.938 - mean_q: -34.859 - mean_eps: 0.406
#
# Interval 39 (38000 steps performed)
#   32/1000 [..............................] - ETA: 6s - reward: -1.0000
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -128.25
#  653/1000 [==================>...........] - ETA: 2s - reward: -0.9923
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -127.20
#  941/1000 [===========================>..] - ETA: 0s - reward: -0.9915
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -125.10
# 1000/1000 [==============================] - 6s 6ms/step - reward: -0.9920
# 8 episodes - episode_reward: -121.250 [-171.000, -69.000] - loss: 0.723 - mae: 23.657 - mean_q: -34.432 - mean_eps: 0.390
#
# Interval 40 (39000 steps performed)
#  227/1000 [=====>........................] - ETA: 5s - reward: -0.9956
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -124.10
#  740/1000 [=====================>........] - ETA: 1s - reward: -0.9932
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -121.90
#  836/1000 [========================>.....] - ETA: 1s - reward: -0.9928
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -120.45
# 1000/1000 [==============================] - 7s 7ms/step - reward: -0.9920
# 8 episodes - episode_reward: -128.375 [-162.000, -91.000] - loss: 0.583 - mae: 23.508 - mean_q: -34.220 - mean_eps: 0.375
#
# Interval 41 (40000 steps performed)
# 1000/1000 [==============================] - 6s 6ms/step - reward: -0.9920
# 8 episodes - episode_reward: -125.375 [-141.000, -104.000] - loss: 0.727 - mae: 23.458 - mean_q: -34.144 - mean_eps: 0.359
#
# Interval 42 (41000 steps performed)
# 1000/1000 [==============================] - 6s 6ms/step - reward: -0.9930
# 7 episodes - episode_reward: -130.571 [-200.000, -92.000] - loss: 0.719 - mae: 23.376 - mean_q: -34.025 - mean_eps: 0.343
#
# Interval 43 (42000 steps performed)
# 1000/1000 [==============================] - 6s 6ms/step - reward: -0.9910
# 9 episodes - episode_reward: -117.667 [-154.000, -102.000] - loss: 0.650 - mae: 23.295 - mean_q: -33.904 - mean_eps: 0.327
#
# Interval 44 (43000 steps performed)
#  401/1000 [===========>..................] - ETA: 3s - reward: -0.9925
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -120.05
#  667/1000 [===================>..........] - ETA: 2s - reward: -0.9925
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -119.40
#  784/1000 [======================>.......] - ETA: 1s - reward: -0.9923
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -118.10
# 1000/1000 [==============================] - 6s 6ms/step - reward: -0.9920
# 8 episodes - episode_reward: -116.000 [-136.000, -104.000] - loss: 0.688 - mae: 23.246 - mean_q: -33.831 - mean_eps: 0.311
#
# Interval 45 (44000 steps performed)
#   19/1000 [..............................] - ETA: 5s - reward: -1.0000
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -114.35
# 1000/1000 [==============================] - 7s 7ms/step - reward: -0.9920
# 8 episodes - episode_reward: -122.625 [-155.000, -107.000] - loss: 0.726 - mae: 23.161 - mean_q: -33.670 - mean_eps: 0.295
#
# Interval 46 (45000 steps performed)
# 1000/1000 [==============================] - 6s 6ms/step - reward: -0.9910
# 9 episodes - episode_reward: -114.778 [-146.000, -85.000] - loss: 0.606 - mae: 23.044 - mean_q: -33.520 - mean_eps: 0.280
#
# Interval 47 (46000 steps performed)
# 1000/1000 [==============================] - 6s 6ms/step - reward: -0.9910
# 9 episodes - episode_reward: -114.444 [-162.000, -96.000] - loss: 0.579 - mae: 22.973 - mean_q: -33.405 - mean_eps: 0.264
#
# Interval 48 (47000 steps performed)
#   65/1000 [>.............................] - ETA: 6s - reward: -1.0000
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -113.70
#  169/1000 [====>.........................] - ETA: 5s - reward: -0.9941
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -112.65
#  397/1000 [==========>...................] - ETA: 4s - reward: -0.9924
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -111.35
#  509/1000 [==============>...............] - ETA: 3s - reward: -0.9902
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -110.00
#  598/1000 [================>.............] - ETA: 2s - reward: -0.9916
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -108.40
# 1000/1000 [==============================] - 7s 7ms/step - reward: -0.9910
# 9 episodes - episode_reward: -107.111 [-153.000, -85.000] - loss: 0.602 - mae: 23.076 - mean_q: -33.579 - mean_eps: 0.248
#
# Interval 49 (48000 steps performed)
#  595/1000 [================>.............] - ETA: 2s - reward: -0.9899
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -106.90
#  868/1000 [=========================>....] - ETA: 0s - reward: -0.9908
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -104.80
#  972/1000 [============================>.] - ETA: 0s - reward: -0.9907
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -103.80
# 1000/1000 [==============================] - 6s 6ms/step - reward: -0.9900
# 10 episodes - episode_reward: -101.400 [-120.000, -70.000] - loss: 0.614 - mae: 23.003 - mean_q: -33.456 - mean_eps: 0.232
#
# Interval 50 (49000 steps performed)
#   68/1000 [=>............................] - ETA: 6s - reward: -1.0000
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -103.60
#  489/1000 [=============>................] - ETA: 3s - reward: -0.9898
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -103.30
# 1000/1000 [==============================] - 7s 7ms/step - reward: -0.9910
# 9 episodes - episode_reward: -103.111 [-146.000, -72.000] - loss: 0.632 - mae: 22.885 - mean_q: -33.264 - mean_eps: 0.216
#
# Interval 51 (50000 steps performed)
#    1/1000 [..............................] - ETA: 9s - reward: -1.0000
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -101.55
#  210/1000 [=====>........................] - ETA: 5s - reward: -0.9905
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -100.70
# 1000/1000 [==============================] - 6s 6ms/step - reward: -0.9910
# 9 episodes - episode_reward: -115.000 [-154.000, -89.000] - loss: 0.626 - mae: 22.652 - mean_q: -32.923 - mean_eps: 0.200
#
# Interval 52 (51000 steps performed)
# 1000/1000 [==============================] - 6s 6ms/step - reward: -0.9900
# 10 episodes - episode_reward: -95.900 [-133.000, -68.000] - loss: 0.572 - mae: 22.590 - mean_q: -32.829 - mean_eps: 0.185
#
# Interval 53 (52000 steps performed)
#  503/1000 [==============>...............] - ETA: 3s - reward: -0.9881
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -99.95
#  584/1000 [================>.............] - ETA: 2s - reward: -0.9897
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -99.45
#  717/1000 [====================>.........] - ETA: 1s - reward: -0.9888
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -99.25
#  890/1000 [=========================>....] - ETA: 0s - reward: -0.9899
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -95.85
#  977/1000 [============================>.] - ETA: 0s - reward: -0.9887
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -95.55
# 1000/1000 [==============================] - 7s 7ms/step - reward: -0.9890
# 11 episodes - episode_reward: -94.273 [-131.000, -66.000] - loss: 0.539 - mae: 22.483 - mean_q: -32.665 - mean_eps: 0.169
#
# Interval 54 (53000 steps performed)
#  746/1000 [=====================>........] - ETA: 1s - reward: -0.9906
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -94.75
#  835/1000 [========================>.....] - ETA: 1s - reward: -0.9904
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -94.65
# 1000/1000 [==============================] - 6s 6ms/step - reward: -0.9900
# 10 episodes - episode_reward: -97.300 [-127.000, -77.000] - loss: 0.594 - mae: 22.261 - mean_q: -32.294 - mean_eps: 0.153
#
# Interval 55 (54000 steps performed)
#  129/1000 [==>...........................] - ETA: 5s - reward: -0.9922
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -94.60
#  221/1000 [=====>........................] - ETA: 5s - reward: -0.9864
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -93.40
# 1000/1000 [==============================] - 7s 7ms/step - reward: -0.9900
# 10 episodes - episode_reward: -97.300 [-115.000, -82.000] - loss: 0.557 - mae: 22.174 - mean_q: -32.155 - mean_eps: 0.137
#
# Interval 56 (55000 steps performed)
# 1000/1000 [==============================] - 6s 6ms/step - reward: -0.9890
# 11 episodes - episode_reward: -94.182 [-152.000, -68.000] - loss: 0.597 - mae: 21.972 - mean_q: -31.857 - mean_eps: 0.121
#
# Interval 57 (56000 steps performed)
#  419/1000 [===========>..................] - ETA: 3s - reward: -0.9905
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -93.20
# 1000/1000 [==============================] - 7s 7ms/step - reward: -0.9900
# 10 episodes - episode_reward: -95.900 [-154.000, -75.000] - loss: 0.571 - mae: 21.962 - mean_q: -31.864 - mean_eps: 0.105
#
# Interval 58 (57000 steps performed)
#  596/1000 [================>.............] - ETA: 2s - reward: -0.9883
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -92.30
#  661/1000 [==================>...........] - ETA: 2s - reward: -0.9894
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -90.95
#  740/1000 [=====================>........] - ETA: 1s - reward: -0.9892
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -90.25
# 1000/1000 [==============================] - 7s 6ms/step - reward: -0.9890
# 11 episodes - episode_reward: -85.636 [-111.000, -70.000] - loss: 0.586 - mae: 22.087 - mean_q: -32.037 - mean_eps: 0.090
#
# Interval 59 (58000 steps performed)
#  337/1000 [=========>....................] - ETA: 4s - reward: -0.9881
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -87.00
#  629/1000 [=================>............] - ETA: 2s - reward: -0.9889
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -86.85
#  710/1000 [====================>.........] - ETA: 1s - reward: -0.9887
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -86.80
#  798/1000 [======================>.......] - ETA: 1s - reward: -0.9887
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -86.55
#  971/1000 [============================>.] - ETA: 0s - reward: -0.9876
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -86.50
# 1000/1000 [==============================] - 7s 7ms/step - reward: -0.9880
# 12 episodes - episode_reward: -87.250 [-120.000, -78.000] - loss: 0.575 - mae: 21.879 - mean_q: -31.689 - mean_eps: 0.074
#
# Interval 60 (59000 steps performed)
#   40/1000 [>.............................] - ETA: 6s - reward: -1.0000
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -84.55
# 1000/1000 [==============================] - 7s 7ms/step - reward: -0.9880
# 12 episodes - episode_reward: -84.167 [-112.000, -63.000] - loss: 0.579 - mae: 21.735 - mean_q: -31.473 - mean_eps: 0.058
#
# Interval 61 (60000 steps performed)
#  325/1000 [========>.....................] - ETA: 4s - reward: -0.9908
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -83.80
# 1000/1000 [==============================] - 6s 6ms/step - reward: -0.9890
# 11 episodes - episode_reward: -85.909 [-121.000, -68.000] - loss: 0.531 - mae: 21.750 - mean_q: -31.524 - mean_eps: 0.050
#
# Interval 62 (61000 steps performed)
#  346/1000 [=========>....................] - ETA: 4s - reward: -0.9884
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -82.90
#  853/1000 [========================>.....] - ETA: 0s - reward: -0.9883
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -82.20
# 1000/1000 [==============================] - 7s 7ms/step - reward: -0.9880
# 12 episodes - episode_reward: -80.917 [-100.000, -70.000] - loss: 0.559 - mae: 21.658 - mean_q: -31.344 - mean_eps: 0.050
#
# Interval 63 (62000 steps performed)
# 1000/1000 [==============================] - 6s 6ms/step - reward: -0.9890
# 11 episodes - episode_reward: -90.364 [-113.000, -61.000] - loss: 0.524 - mae: 21.660 - mean_q: -31.341 - mean_eps: 0.050
#
# Interval 64 (63000 steps performed)
# 1000/1000 [==============================] - 6s 6ms/step - reward: -0.9880
# 12 episodes - episode_reward: -82.833 [-119.000, -69.000] - loss: 0.572 - mae: 21.552 - mean_q: -31.173 - mean_eps: 0.050
#
# Interval 65 (64000 steps performed)
# 1000/1000 [==============================] - 6s 6ms/step - reward: -0.9880
# 12 episodes - episode_reward: -86.333 [-127.000, -63.000] - loss: 0.559 - mae: 21.576 - mean_q: -31.200 - mean_eps: 0.050
#
# Interval 66 (65000 steps performed)
#  796/1000 [======================>.......] - ETA: 1s - reward: -0.9887
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -81.80
#  889/1000 [=========================>....] - ETA: 0s - reward: -0.9888
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -81.50
# 1000/1000 [==============================] - 6s 6ms/step - reward: -0.9890
# 11 episodes - episode_reward: -81.091 [-110.000, -62.000] - loss: 0.550 - mae: 21.548 - mean_q: -31.157 - mean_eps: 0.050
#
# Interval 67 (66000 steps performed)
# 1000/1000 [==============================] - 7s 7ms/step - reward: -0.9890
# 11 episodes - episode_reward: -98.091 [-202.000, -69.000] - loss: 0.608 - mae: 21.507 - mean_q: -31.066 - mean_eps: 0.050
#
# Interval 68 (67000 steps performed)
# 1000/1000 [==============================] - 6s 6ms/step - reward: -0.9890
# 11 episodes - episode_reward: -82.091 [-121.000, -62.000] - loss: 0.581 - mae: 21.513 - mean_q: -31.056 - mean_eps: 0.050
#
# Interval 69 (68000 steps performed)
# 1000/1000 [==============================] - 6s 6ms/step - reward: -0.9880
# 12 episodes - episode_reward: -86.833 [-108.000, -61.000] - loss: 0.557 - mae: 21.409 - mean_q: -30.928 - mean_eps: 0.050
#
# Interval 70 (69000 steps performed)
#  650/1000 [==================>...........] - ETA: 2s - reward: -0.9877
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -81.45
#  724/1000 [====================>.........] - ETA: 1s - reward: -0.9876
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -81.00
#  822/1000 [=======================>......] - ETA: 1s - reward: -0.9866
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -80.25
#  980/1000 [============================>.] - ETA: 0s - reward: -0.9878
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -79.55
# 1000/1000 [==============================] - 7s 7ms/step - reward: -0.9870
# 13 episodes - episode_reward: -78.538 [-93.000, -61.000] - loss: 0.577 - mae: 21.280 - mean_q: -30.736 - mean_eps: 0.050
#
# Interval 71 (70000 steps performed)
#  307/1000 [========>.....................] - ETA: 4s - reward: -0.9902
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -79.50
#  390/1000 [==========>...................] - ETA: 3s - reward: -0.9897
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -78.55
# 1000/1000 [==============================] - 6s 6ms/step - reward: -0.9890
# 11 episodes - episode_reward: -86.545 [-109.000, -70.000] - loss: 0.578 - mae: 21.312 - mean_q: -30.760 - mean_eps: 0.050
#
# Interval 72 (71000 steps performed)
# 1000/1000 [==============================] - 7s 7ms/step - reward: -0.9870
# 13 episodes - episode_reward: -79.846 [-106.000, -62.000] - loss: 0.570 - mae: 21.187 - mean_q: -30.568 - mean_eps: 0.050
#
# Interval 73 (72000 steps performed)
#  533/1000 [==============>...............] - ETA: 2s - reward: -0.9887
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -78.30
#  614/1000 [=================>............] - ETA: 2s - reward: -0.9886
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -78.15
#  715/1000 [====================>.........] - ETA: 1s - reward: -0.9874
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -78.00
# 1000/1000 [==============================] - 6s 6ms/step - reward: -0.9880
# 12 episodes - episode_reward: -77.333 [-102.000, -63.000] - loss: 0.556 - mae: 21.333 - mean_q: -30.816 - mean_eps: 0.050
#
# Interval 74 (73000 steps performed)
#  239/1000 [======>.......................] - ETA: 4s - reward: -0.9874
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -77.90
#  310/1000 [========>.....................] - ETA: 4s - reward: -0.9871
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -77.45
#  482/1000 [=============>................] - ETA: 3s - reward: -0.9876
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -77.25
# 1000/1000 [==============================] - 7s 7ms/step - reward: -0.9870
# 13 episodes - episode_reward: -77.692 [-99.000, -63.000] - loss: 0.555 - mae: 21.096 - mean_q: -30.418 - mean_eps: 0.050
#
# Interval 75 (74000 steps performed)
#   31/1000 [..............................] - ETA: 7s - reward: -1.0000
# [🏆] ¡Récord superado! Nuevo mejor cerebro guardado con media: -77.20
# 1000/1000 [==============================] - 6s 6ms/step - reward: -0.9890
# 11 episodes - episode_reward: -87.545 [-126.000, -63.000] - loss: 0.533 - mae: 21.016 - mean_q: -30.322 - mean_eps: 0.050
#
# Interval 76 (75000 steps performed)
# 1000/1000 [==============================] - 6s 6ms/step - reward: -0.9890
# 11 episodes - episode_reward: -90.455 [-144.000, -63.000] - loss: 0.552 - mae: 20.991 - mean_q: -30.261 - mean_eps: 0.050
#
# Interval 77 (76000 steps performed)
# 1000/1000 [==============================] - 7s 7ms/step - reward: -0.9880
# 12 episodes - episode_reward: -80.750 [-103.000, -61.000] - loss: 0.525 - mae: 20.998 - mean_q: -30.284 - mean_eps: 0.050
#
# Interval 78 (77000 steps performed)
# 1000/1000 [==============================] - 6s 6ms/step - reward: -0.9880
# 12 episodes - episode_reward: -83.083 [-102.000, -68.000] - loss: 0.486 - mae: 20.945 - mean_q: -30.204 - mean_eps: 0.050
#
# Interval 79 (78000 steps performed)
# 1000/1000 [==============================] - 6s 6ms/step - reward: -0.9870
# 13 episodes - episode_reward: -77.615 [-100.000, -62.000] - loss: 0.504 - mae: 20.875 - mean_q: -30.074 - mean_eps: 0.050
#
# Interval 80 (79000 steps performed)
# 1000/1000 [==============================] - 7s 7ms/step - reward: -0.9880
# done, took 500.561 seconds

# %%
dqn_p2.save_weights(weights_filename_p2, overwrite=True)

print("Pesos finales guardados en:")
print(weights_filename_p2)

print("Pesos best:")
print(best_weights_path_p2)
# Out:
# Pesos finales guardados en:
# C:\Users\kevin\Downloads\ESTUDIO MASTER EN IA\Aprendizaje por refuerzo\PROYECTO\Proyecto RL\dqn_Acrobot-v1_p2_weights.h5f
# Pesos best:
# C:\Users\kevin\Downloads\ESTUDIO MASTER EN IA\Aprendizaje por refuerzo\PROYECTO\Proyecto RL\dqn_Acrobot-v1_p2_best.h5f

# %%
# Evaluación de la propuesta p2 usando los mejores pesos guardados

dqn_p2.load_weights(best_weights_path_p2)
dqn_p2.test_policy = EpsGreedyQPolicy(eps=0.0)

env_test_p2 = gym.make(env_name)

history_test_p2 = dqn_p2.test(
    env_test_p2,
    nb_episodes=100,
    visualize=False,
    verbose=1
)

env_test_p2.close()

test_rewards_p2 = history_test_p2.history['episode_reward']

print("MEDIA TEST PROPUESTA P2:", np.mean(test_rewards_p2))
print("MEJOR EPISODIO:", np.max(test_rewards_p2))
print("PEOR EPISODIO:", np.min(test_rewards_p2))
print("DESVIACIÓN ESTÁNDAR:", np.std(test_rewards_p2))
# Out:
# Testing for 100 episodes ...
# Episode 1: reward: -63.000, steps: 64
# Episode 2: reward: -62.000, steps: 63
# Episode 3: reward: -63.000, steps: 64
# Episode 4: reward: -63.000, steps: 64
# Episode 5: reward: -94.000, steps: 95
# Episode 6: reward: -87.000, steps: 88
# Episode 7: reward: -88.000, steps: 89
# Episode 8: reward: -80.000, steps: 81
# Episode 9: reward: -72.000, steps: 73
# Episode 10: reward: -79.000, steps: 80
# Episode 11: reward: -62.000, steps: 63
# Episode 12: reward: -116.000, steps: 117
# Episode 13: reward: -70.000, steps: 71
# Episode 14: reward: -63.000, steps: 64
# Episode 15: reward: -87.000, steps: 88
# Episode 16: reward: -71.000, steps: 72
# Episode 17: reward: -63.000, steps: 64
# Episode 18: reward: -63.000, steps: 64
# Episode 19: reward: -85.000, steps: 86
# Episode 20: reward: -69.000, steps: 70
# Episode 21: reward: -71.000, steps: 72
# Episode 22: reward: -70.000, steps: 71
# Episode 23: reward: -100.000, steps: 101
# Episode 24: reward: -62.000, steps: 63
# Episode 25: reward: -70.000, steps: 71
# Episode 26: reward: -63.000, steps: 64
# Episode 27: reward: -71.000, steps: 72
# Episode 28: reward: -71.000, steps: 72
# Episode 29: reward: -79.000, steps: 80
# Episode 30: reward: -69.000, steps: 70
# Episode 31: reward: -62.000, steps: 63
# Episode 32: reward: -63.000, steps: 64
# Episode 33: reward: -64.000, steps: 65
# Episode 34: reward: -70.000, steps: 71
# Episode 35: reward: -85.000, steps: 86
# Episode 36: reward: -71.000, steps: 72
# Episode 37: reward: -70.000, steps: 71
# Episode 38: reward: -70.000, steps: 71
# Episode 39: reward: -86.000, steps: 87
# Episode 40: reward: -72.000, steps: 73
# Episode 41: reward: -84.000, steps: 85
# Episode 42: reward: -76.000, steps: 77
# Episode 43: reward: -104.000, steps: 105
# Episode 44: reward: -87.000, steps: 88
# Episode 45: reward: -63.000, steps: 64
# Episode 46: reward: -82.000, steps: 83
# Episode 47: reward: -70.000, steps: 71
# Episode 48: reward: -64.000, steps: 65
# Episode 49: reward: -71.000, steps: 72
# Episode 50: reward: -91.000, steps: 92
# Episode 51: reward: -62.000, steps: 63
# Episode 52: reward: -84.000, steps: 85
# Episode 53: reward: -70.000, steps: 71
# Episode 54: reward: -64.000, steps: 65
# Episode 55: reward: -88.000, steps: 89
# Episode 56: reward: -71.000, steps: 72
# Episode 57: reward: -87.000, steps: 88
# Episode 58: reward: -70.000, steps: 71
# Episode 59: reward: -64.000, steps: 65
# Episode 60: reward: -110.000, steps: 111
# Episode 61: reward: -62.000, steps: 63
# Episode 62: reward: -64.000, steps: 65
# Episode 63: reward: -71.000, steps: 72
# Episode 64: reward: -71.000, steps: 72
# Episode 65: reward: -69.000, steps: 70
# Episode 66: reward: -78.000, steps: 79
# Episode 67: reward: -63.000, steps: 64
# Episode 68: reward: -62.000, steps: 63
# Episode 69: reward: -79.000, steps: 80
# Episode 70: reward: -63.000, steps: 64
# Episode 71: reward: -74.000, steps: 75
# Episode 72: reward: -83.000, steps: 84
# Episode 73: reward: -71.000, steps: 72
# Episode 74: reward: -64.000, steps: 65
# Episode 75: reward: -75.000, steps: 76
# Episode 76: reward: -63.000, steps: 64
# Episode 77: reward: -75.000, steps: 76
# Episode 78: reward: -71.000, steps: 72
# Episode 79: reward: -80.000, steps: 81
# Episode 80: reward: -71.000, steps: 72
# Episode 81: reward: -91.000, steps: 92
# Episode 82: reward: -134.000, steps: 135
# Episode 83: reward: -63.000, steps: 64
# Episode 84: reward: -86.000, steps: 87
# Episode 85: reward: -79.000, steps: 80
# Episode 86: reward: -87.000, steps: 88
# Episode 87: reward: -69.000, steps: 70
# Episode 88: reward: -121.000, steps: 122
# Episode 89: reward: -75.000, steps: 76
# Episode 90: reward: -69.000, steps: 70
# Episode 91: reward: -71.000, steps: 72
# Episode 92: reward: -70.000, steps: 71
# Episode 93: reward: -161.000, steps: 162
# Episode 94: reward: -72.000, steps: 73
# Episode 95: reward: -61.000, steps: 62
# Episode 96: reward: -70.000, steps: 71
# Episode 97: reward: -110.000, steps: 111
# Episode 98: reward: -99.000, steps: 100
# Episode 99: reward: -70.000, steps: 71
# Episode 100: reward: -75.000, steps: 76
# MEDIA TEST PROPUESTA P2: -76.43
# MEJOR EPISODIO: -61.0
# PEOR EPISODIO: -161.0
# DESVIACIÓN ESTÁNDAR: 16.25623265089424

# %%
with open(log_filename_p2, 'r') as f:
    log_p2 = json.load(f)

episode_reward_p2 = log_p2['episode_reward']
nb_episode_steps_p2 = log_p2['nb_episode_steps']
nb_steps_p2 = log_p2['nb_steps']

print("Episodios registrados:", len(episode_reward_p2))
print("Último paso registrado:", nb_steps_p2[-1])
print("Recompensa media entrenamiento:", np.mean(episode_reward_p2))
print("Mejor recompensa entrenamiento:", np.max(episode_reward_p2))
print("Peor recompensa entrenamiento:", np.min(episode_reward_p2))
# Out:
# Episodios registrados: 605
# Último paso registrado: 79969
# Recompensa media entrenamiento: -131.21322314049587
# Mejor recompensa entrenamiento: -61.0
# Peor recompensa entrenamiento: -500.0

# %%
video_folder_p2 = os.path.join(drive_root, "videos_proyecto_p2")

env_video_p2 = gym.make(env_name)

env_video_p2 = Monitor(
    env_video_p2,
    video_folder_p2,
    force=True,
    video_callable=lambda episode_id: True
)

dqn_p2.load_weights(best_weights_path_p2)
dqn_p2.test_policy = EpsGreedyQPolicy(eps=0.0)

print("Grabando vídeo de la propuesta p2...")

dqn_p2.test(
    env_video_p2,
    nb_episodes=3,
    visualize=False,
    verbose=1
)

env_video_p2.close()

print("Vídeo guardado en:", video_folder_p2)
# Out:
# Grabando vídeo de la propuesta p2...
# Testing for 3 episodes ...
# Episode 1: reward: -78.000, steps: 79
# Episode 2: reward: -70.000, steps: 71
# Episode 3: reward: -63.000, steps: 64
# Vídeo guardado en: C:\Users\kevin\Downloads\ESTUDIO MASTER EN IA\Aprendizaje por refuerzo\PROYECTO\Proyecto RL\videos_proyecto_p2

# %%
plt.figure(figsize=(12, 5))
plt.plot(episode_reward_p2)
plt.title('Propuesta de mejora 1 - Recompensa por episodio')
plt.xlabel('Episodio')
plt.ylabel('Recompensa')
plt.grid(True)
plt.show()

# %% [markdown]
# Se muestra una fase de aprendizaje inicial con episodios en -500, seguida de una mejora progresiva que se estabiliza en un rango mucho más favorable (aproximadamente -60 a -150), manteniéndose ahí de forma sostenida durante la mayor parte del entrenamiento, sin los retrocesos abruptos que sí aparecen en la propuesta base.

# %%
window = 20

moving_avg_p2 = np.convolve(
    episode_reward_p2,
    np.ones(window) / window,
    mode='valid'
)

plt.figure(figsize=(12, 5))
plt.plot(range(window - 1, len(episode_reward_p2)), moving_avg_p2)
plt.title('Propuesta de mejora 1 - Media móvil de recompensa')
plt.xlabel('Episodio')
plt.ylabel('Recompensa media')
plt.grid(True)
plt.show()

# %% [markdown]
# Presenta una curva de aprendizaje bien definida: una subida marcada al inicio y una estabilización posterior en torno a -100, sin caídas significativas hacia el final del entrenamiento.

# %%
plt.figure(figsize=(12, 5))
plt.plot(test_rewards_p2, marker='o')
plt.title('Propuesta de mejora 1 - Recompensa en 100 episodios de test')
plt.xlabel('Episodio de test')
plt.ylabel('Recompensa')
plt.grid(True)
plt.show()

# %% [markdown]
# Los resultados de evaluación refuerzan la solidez del entrenamiento: La política se comporta de forma consistente y sin fallos: ningún episodio termina en -500, y el rango de recompensas es estrecho y predecible.

# %%
base_log_path = os.path.join(drive_root, f'dqn_{env_name}_p1_log.json')
p2_log_path = log_filename_p2

with open(base_log_path, 'r') as f:
    log_base = json.load(f)

with open(p2_log_path, 'r') as f:
    log_p2 = json.load(f)

rewards_base = log_base['episode_reward']
rewards_p2 = log_p2['episode_reward']

window = 20

media_base = np.convolve(
    rewards_base,
    np.ones(window) / window,
    mode='valid'
)

media_p2 = np.convolve(
    rewards_p2,
    np.ones(window) / window,
    mode='valid'
)

plt.figure(figsize=(12, 5))
plt.plot(range(window - 1, len(rewards_base)), media_base, label='Propuesta base p1')
plt.plot(range(window - 1, len(rewards_p2)), media_p2, label='Propuesta mejora p2')
plt.title('Comparación base vs propuesta de mejora 1')
plt.xlabel('Episodio')
plt.ylabel('Recompensa media móvil (Promedio cada 20 episodios)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# La gráfica comparativa (media móvil de ambas propuestas) muestra trayectorias claramente distintas: la propuesta base mejora al inicio, pero sufre una caída pronunciada de vuelta hacia -500 en la parte media del entrenamiento, y solo recupera parcialmente el nivel alcanzado antes de terminar el log. La propuesta de mejora 1, en cambio, converge de forma mucho más rápida y sostenida hacia valores cercanos a -100, sin mostrar retrocesos comparables. Esto se traduce directamente en los resultados de test: -177.53 en la base frente a -75.32 en la mejora, con una diferencia adicional en consistencia (la base aún registra fallos ocasionales en test, mientras que la mejora no registra ninguno).

# %% [markdown]
# ## 4.1 Conclusión.

# %% [markdown]
# Los resultados confirman que la propuesta base logra un aprendizaje real pero inestable: mejora su desempeño respecto al fallo total, pero sufre retrocesos significativos durante el entrenamiento y conserva episodios de fallo tanto en entrenamiento como en test. La propuesta de mejora 1, basada en una exploración progresiva con epsilon decreciente, no solo obtiene una recompensa media muy superior, sino que logra una convergencia mucho más estable y una política de test completamente libre de fallos. Esto indica que la principal limitación de la propuesta base —una exploración insuficiente e inconsistente a lo largo del entrenamiento— fue efectivamente resuelta por la propuesta de mejora, que logra un comportamiento no solo mejor en promedio, sino considerablemente más fiable y repetible.

# %% [markdown]
# ## 5. Propuesta de mejora 2: Double DQN (DDQN).
#
# DDQN corrige el sesgo de sobreestimación de Q-learning, desacoplando la *selección* de la acción (red online) de la *evaluación* de su valor (red target). Durante el entrenamiento se detectó un colapso hacia el final (*catastrophic forgetting*), confirmado mediante inspección directa de los Q-valores en un rollout — la red convergía a una acción fija sin importar el estado. Se recuperó y validó el checkpoint intermedio de 90,000 pasos.
#
# **Resultado de test:** 100% de éxito, media **-84.01**, equivalente a la base.
#
# Esto sugiere que, en un espacio de acciones tan reducido (3 acciones), el sesgo de sobreestimación no era un factor limitante relevante para una base ya bien configurada — el aporte de DDQN aquí es más una garantía teórica de robustez que una mejora medible en este entorno particular.

# %% [markdown]
# ## 5. Propuesta de mejora 3: Ajuste de exploración (Boltzmann).
#
# En lugar de mover un parámetro de la misma política epsilon-greedy, se sustituyó el **mecanismo completo de exploración** por una política Boltzmann, que pondera la probabilidad de cada acción según su Q-valor relativo:
#
# $$P(a \mid s) = \frac{\exp(Q(s,a)/\tau)}{\sum_{a'} \exp(Q(s,a')/\tau)}$$
#
# A diferencia de epsilon-greedy —donde la tasa de exploración es una variable que se controla explícitamente y decae de forma programada—, en Boltzmann la exploración emerge indirectamente de qué tan diferenciados estén los Q-valores entre sí. Esto implica un *trade-off*: se sacrifica el control directo sobre "cuánto explora el agente en cada momento" a cambio de una exploración *informada* por la calidad relativa de las acciones, en vez de una exploración puramente aleatoria y uniforme.
#
# **Resultado de test:** 100% de éxito, media **-78.40**, mejor **-61**, peor **-143** — la mejor media de las cuatro propuestas y el peor caso más contenido después de DDQN.
#
# **Hallazgo relevante:** durante el entrenamiento, la media de recompensa de Boltzmann se estabilizó entre -150 y -170, sin bajar de ese rango — aparentemente peor que las otras tres propuestas, que en sus últimos intervalos ya rondaban -90. Esto se debe a que Boltzmann **nunca "apaga" su exploración** con el tiempo como sí lo hace epsilon-greedy con su `value_min` fijo: sigue muestreando proporcionalmente a los Q-valores durante todo el entrenamiento. En el test, en cambio, esa misma política explota naturalmente las acciones de mayor Q-valor porque la red ya aprendió bien, lo que explica el salto a -78.40. Esto ilustra que **la recompensa media de entrenamiento puede ser un proxy engañoso** de la calidad real de la política final.
